# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit

from sklearn.model_selection import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV

warnings.filterwarnings('ignore')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# 基本変数定義

# %%
sampling_flg=0 #サンプリング有無をコントロール
submit_flg=1 #保存するかをコントロール（サンプリングしない時のみ）

#SEED=12345
sample_num=5000
fold_num=5

#train関連
train_dir='../../02_feature/101_train.csv'
train_drop_col=['ID_code', 'target']
train_label='target'

#test関連
test_dir='../../02_feature/101_test.csv'
test_drop_col=['ID_code']

#結果ファイル関連　nameは自分の名前に変更する
train_preds_dir='../../03_predict_train/oka_219_LightGBM_seed_train.csv'
test_preds_dir='../../04_predict_test/oka_219_LightGBM_seed_submission.csv'
save_col_name='oof_xgb'

sample_submission_dir='../../01_input/sample_submission.csv'
submission_target_col_name='target'
submission_id_col_name='ID_code'

# %% [markdown]
# 前処理

# %%
#ロード
train_df=pd.read_csv(train_dir)
test_df=pd.read_csv(test_dir)

# %%
#サンプリング
if sampling_flg ==1:
    train_df=train_df.sample(n=sample_num,random_state=1)
    test_df=test_df.sample(n=sample_num,random_state=1)

# %%
#x,y作成
x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]
x_test=test_df.drop(test_drop_col,axis=1)

# %% [markdown]
# モデル実行

# %%
#model_param
all_oof_preds = np.zeros((len(x_train), 1))
all_test_preds = np.zeros((len(x_test), 1))
for SEED in range(0,9):
    print(SEED)
    param = {
            'num_leaves': 2,
            'max_bin': 63,
            'min_data_in_leaf': 45,
            'learning_rate': 0.01,
            'min_sum_hessian_in_leaf': 0.000446,
            'bagging_fraction': 0.55, 
            'bagging_freq': 5, 
            'max_depth': 14,
            'save_binary': True,
            'seed': SEED,
            'feature_fraction_seed': SEED,
            'feature_fraction': 0.51,
            'bagging_seed': SEED,
            'drop_seed': SEED,
            'data_random_seed': SEED,
            'objective': 'binary',
            'boosting_type': 'gbdt',
            'verbose': 1,
            'metric': 'auc',
            'is_unbalance': True,
            'boost_from_average': False,
        }

    folds = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=SEED)
    oof_preds = np.zeros((len(x_train), 1))
    test_preds = np.zeros((len(x_test), 1))

    for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train.values, y_train.values)):
        print("\n")
        print("Fold {}".format(fold_))
        trn_x,trn_y = x_train.iloc[trn_idx], y_train.iloc[trn_idx]
        val_x,val_y = x_train.iloc[val_idx], y_train.iloc[val_idx]
        trn_data = lgb.Dataset(trn_x,trn_y)
        val_data = lgb.Dataset(val_x,val_y)

        num_round = 50000
        clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 2000)
        val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
        test_pred = clf.predict(x_test, num_iteration=clf.best_iteration)

        print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
        #print("val = {}".format(val_pred)
        oof_preds[val_idx, :] = val_pred.reshape((-1, 1))
        test_preds += test_pred.reshape((-1, 1))

    test_preds /= fold_num
    roc_score = roc_auc_score(y_train, oof_preds.ravel())
    print("Overall AUC = {}".format(roc_score))
    
    all_oof_preds+=oof_preds
    all_test_preds+=test_preds
    
all_oof_preds/=10
all_test_preds/=10
# Out:
# 0
#
#
# Fold 0
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.794203	valid_1's auc: 0.786541
# [2000]	training's auc: 0.829256	valid_1's auc: 0.81924
# [3000]	training's auc: 0.848083	valid_1's auc: 0.83773
# [4000]	training's auc: 0.860627	valid_1's auc: 0.849917
# [5000]	training's auc: 0.86973	valid_1's auc: 0.858279
# [6000]	training's auc: 0.87633	valid_1's auc: 0.864682
# [7000]	training's auc: 0.881283	valid_1's auc: 0.869606
# [8000]	training's auc: 0.88546	valid_1's auc: 0.873361
# [9000]	training's auc: 0.888742	valid_1's auc: 0.876347
# [10000]	training's auc: 0.89159	valid_1's auc: 0.8791
# [11000]	training's auc: 0.893955	valid_1's auc: 0.881466
# [12000]	training's auc: 0.896026	valid_1's auc: 0.883303
# [13000]	training's auc: 0.897843	valid_1's auc: 0.885152
# [14000]	training's auc: 0.899444	valid_1's auc: 0.886622
# [15000]	training's auc: 0.90077	valid_1's auc: 0.887653
# [16000]	training's auc: 0.901987	valid_1's auc: 0.88876
# [17000]	training's auc: 0.903079	valid_1's auc: 0.889741
# [18000]	training's auc: 0.903927	valid_1's auc: 0.890556
# [19000]	training's auc: 0.904767	valid_1's auc: 0.891348
# [20000]	training's auc: 0.905512	valid_1's auc: 0.892069
# [21000]	training's auc: 0.906199	valid_1's auc: 0.892629
# [22000]	training's auc: 0.90686	valid_1's auc: 0.893222
# [23000]	training's auc: 0.907476	valid_1's auc: 0.893736
# [24000]	training's auc: 0.907979	valid_1's auc: 0.89409
# [25000]	training's auc: 0.90846	valid_1's auc: 0.894445
# [26000]	training's auc: 0.908913	valid_1's auc: 0.894729
# [27000]	training's auc: 0.909331	valid_1's auc: 0.895062
# [28000]	training's auc: 0.909681	valid_1's auc: 0.895297
# [29000]	training's auc: 0.909997	valid_1's auc: 0.895527
# [30000]	training's auc: 0.910328	valid_1's auc: 0.895709
# [31000]	training's auc: 0.910597	valid_1's auc: 0.895847
# [32000]	training's auc: 0.910862	valid_1's auc: 0.896041
# [33000]	training's auc: 0.911128	valid_1's auc: 0.896131
# [34000]	training's auc: 0.911365	valid_1's auc: 0.89626
# [35000]	training's auc: 0.911611	valid_1's auc: 0.896356
# [36000]	training's auc: 0.91183	valid_1's auc: 0.896457
# [37000]	training's auc: 0.912035	valid_1's auc: 0.896471
# [38000]	training's auc: 0.912253	valid_1's auc: 0.896497
# [39000]	training's auc: 0.912462	valid_1's auc: 0.896548
# [40000]	training's auc: 0.912661	valid_1's auc: 0.896516
# [41000]	training's auc: 0.912848	valid_1's auc: 0.89652
# Early stopping, best iteration is:
# [39428]	training's auc: 0.912553	valid_1's auc: 0.89656
# AUC = 0.8965601801171735
#
#
# Fold 1
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.79103	valid_1's auc: 0.774692
# [2000]	training's auc: 0.829374	valid_1's auc: 0.814754
# [3000]	training's auc: 0.847844	valid_1's auc: 0.833142
# [4000]	training's auc: 0.860454	valid_1's auc: 0.846303
# [5000]	training's auc: 0.869451	valid_1's auc: 0.855653
# [6000]	training's auc: 0.875717	valid_1's auc: 0.862413
# [7000]	training's auc: 0.881336	valid_1's auc: 0.86791
# [8000]	training's auc: 0.885458	valid_1's auc: 0.871803
# [9000]	training's auc: 0.888769	valid_1's auc: 0.875433
# [10000]	training's auc: 0.891464	valid_1's auc: 0.878038
# [11000]	training's auc: 0.893911	valid_1's auc: 0.880421
# [12000]	training's auc: 0.896014	valid_1's auc: 0.882756
# [13000]	training's auc: 0.89776	valid_1's auc: 0.884203
# [14000]	training's auc: 0.899342	valid_1's auc: 0.885885
# [15000]	training's auc: 0.90076	valid_1's auc: 0.88718
# [16000]	training's auc: 0.901978	valid_1's auc: 0.888351
# [17000]	training's auc: 0.903021	valid_1's auc: 0.889298
# [18000]	training's auc: 0.903994	valid_1's auc: 0.890227
# [19000]	training's auc: 0.904879	valid_1's auc: 0.89102
# [20000]	training's auc: 0.905652	valid_1's auc: 0.891576
# [21000]	training's auc: 0.90633	valid_1's auc: 0.892164
# [22000]	training's auc: 0.906979	valid_1's auc: 0.892736
# [23000]	training's auc: 0.907574	valid_1's auc: 0.893181
# [24000]	training's auc: 0.908157	valid_1's auc: 0.893592
# [25000]	training's auc: 0.908574	valid_1's auc: 0.894
# [26000]	training's auc: 0.909053	valid_1's auc: 0.894396
# [27000]	training's auc: 0.909423	valid_1's auc: 0.894647
# [28000]	training's auc: 0.909758	valid_1's auc: 0.894915
# [29000]	training's auc: 0.91011	valid_1's auc: 0.89512
# [30000]	training's auc: 0.910426	valid_1's auc: 0.895374
# [31000]	training's auc: 0.910732	valid_1's auc: 0.895489
# [32000]	training's auc: 0.911037	valid_1's auc: 0.89561
# [33000]	training's auc: 0.911297	valid_1's auc: 0.895724
# [34000]	training's auc: 0.911552	valid_1's auc: 0.895814
# [35000]	training's auc: 0.911808	valid_1's auc: 0.895835
# [36000]	training's auc: 0.912019	valid_1's auc: 0.895935
# [37000]	training's auc: 0.912247	valid_1's auc: 0.896049
# [38000]	training's auc: 0.912447	valid_1's auc: 0.89613
# [39000]	training's auc: 0.912658	valid_1's auc: 0.896158
# [40000]	training's auc: 0.912868	valid_1's auc: 0.896149
# [41000]	training's auc: 0.913064	valid_1's auc: 0.896132
# [42000]	training's auc: 0.913281	valid_1's auc: 0.896079
# Early stopping, best iteration is:
# [40117]	training's auc: 0.912888	valid_1's auc: 0.896182
# AUC = 0.8961817465575046
#
#
# Fold 2
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.78887	valid_1's auc: 0.78652
# [2000]	training's auc: 0.826802	valid_1's auc: 0.823096
# [3000]	training's auc: 0.847689	valid_1's auc: 0.842441
# [4000]	training's auc: 0.860025	valid_1's auc: 0.853701
# [5000]	training's auc: 0.869229	valid_1's auc: 0.861778
# [6000]	training's auc: 0.875671	valid_1's auc: 0.867428
# [7000]	training's auc: 0.880793	valid_1's auc: 0.871992
# [8000]	training's auc: 0.884943	valid_1's auc: 0.875762
# [9000]	training's auc: 0.888299	valid_1's auc: 0.878622
# [10000]	training's auc: 0.891213	valid_1's auc: 0.881247
# [11000]	training's auc: 0.893634	valid_1's auc: 0.883268
# [12000]	training's auc: 0.895681	valid_1's auc: 0.885154
# [13000]	training's auc: 0.897464	valid_1's auc: 0.886723
# [14000]	training's auc: 0.899049	valid_1's auc: 0.887916
# [15000]	training's auc: 0.900556	valid_1's auc: 0.889175
# [16000]	training's auc: 0.901736	valid_1's auc: 0.890208
# [17000]	training's auc: 0.902855	valid_1's auc: 0.891222
# [18000]	training's auc: 0.903773	valid_1's auc: 0.89204
# [19000]	training's auc: 0.904631	valid_1's auc: 0.892756
# [20000]	training's auc: 0.905426	valid_1's auc: 0.893346
# [21000]	training's auc: 0.906126	valid_1's auc: 0.893864
# [22000]	training's auc: 0.906783	valid_1's auc: 0.894286
# [23000]	training's auc: 0.907322	valid_1's auc: 0.894544
# [24000]	training's auc: 0.907838	valid_1's auc: 0.894919
# [25000]	training's auc: 0.908346	valid_1's auc: 0.895165
# [26000]	training's auc: 0.908814	valid_1's auc: 0.895488
# [27000]	training's auc: 0.9092	valid_1's auc: 0.895746
# [28000]	training's auc: 0.909565	valid_1's auc: 0.896083
# [29000]	training's auc: 0.90992	valid_1's auc: 0.896238
# [30000]	training's auc: 0.910252	valid_1's auc: 0.89645
# [31000]	training's auc: 0.910533	valid_1's auc: 0.896569
# [32000]	training's auc: 0.910835	valid_1's auc: 0.896716
# [33000]	training's auc: 0.911109	valid_1's auc: 0.896747
# [34000]	training's auc: 0.911343	valid_1's auc: 0.896856
# [35000]	training's auc: 0.911579	valid_1's auc: 0.896934
# [36000]	training's auc: 0.911804	valid_1's auc: 0.897046
# [37000]	training's auc: 0.912027	valid_1's auc: 0.897105
# [38000]	training's auc: 0.912226	valid_1's auc: 0.897193
# [39000]	training's auc: 0.912422	valid_1's auc: 0.897219
# [40000]	training's auc: 0.912632	valid_1's auc: 0.897214
# [41000]	training's auc: 0.912827	valid_1's auc: 0.897192
# Early stopping, best iteration is:
# [39274]	training's auc: 0.912476	valid_1's auc: 0.897262
# AUC = 0.8972615798163159
#
#
# Fold 3
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.788867	valid_1's auc: 0.790946
# [2000]	training's auc: 0.826801	valid_1's auc: 0.828732
# [3000]	training's auc: 0.84604	valid_1's auc: 0.84775
# [4000]	training's auc: 0.858528	valid_1's auc: 0.860013
# [5000]	training's auc: 0.867069	valid_1's auc: 0.86848
# [6000]	training's auc: 0.873796	valid_1's auc: 0.875113
# [7000]	training's auc: 0.878697	valid_1's auc: 0.879805
# [8000]	training's auc: 0.883205	valid_1's auc: 0.883717
# [9000]	training's auc: 0.886804	valid_1's auc: 0.886994
# [10000]	training's auc: 0.889636	valid_1's auc: 0.889491
# [11000]	training's auc: 0.891924	valid_1's auc: 0.891512
# [12000]	training's auc: 0.8943	valid_1's auc: 0.893635
# [13000]	training's auc: 0.896048	valid_1's auc: 0.894971
# [14000]	training's auc: 0.897566	valid_1's auc: 0.896153
# [15000]	training's auc: 0.899094	valid_1's auc: 0.897454
# [16000]	training's auc: 0.900294	valid_1's auc: 0.898424
# [17000]	training's auc: 0.901396	valid_1's auc: 0.899134
# [18000]	training's auc: 0.902402	valid_1's auc: 0.899796
# [19000]	training's auc: 0.903235	valid_1's auc: 0.90038
# [20000]	training's auc: 0.903961	valid_1's auc: 0.90091
# [21000]	training's auc: 0.904613	valid_1's auc: 0.901259
# [22000]	training's auc: 0.905284	valid_1's auc: 0.901657
# [23000]	training's auc: 0.905902	valid_1's auc: 0.901987
# [24000]	training's auc: 0.906424	valid_1's auc: 0.90233
# [25000]	training's auc: 0.906944	valid_1's auc: 0.902614
# [26000]	training's auc: 0.907386	valid_1's auc: 0.902722
# [27000]	training's auc: 0.907787	valid_1's auc: 0.902939
# [28000]	training's auc: 0.908139	valid_1's auc: 0.903056
# [29000]	training's auc: 0.908499	valid_1's auc: 0.903131
# [30000]	training's auc: 0.908833	valid_1's auc: 0.903241
# [31000]	training's auc: 0.909129	valid_1's auc: 0.903284
# [32000]	training's auc: 0.909385	valid_1's auc: 0.903407
# [33000]	training's auc: 0.909677	valid_1's auc: 0.90348
# [34000]	training's auc: 0.909909	valid_1's auc: 0.903566
# [35000]	training's auc: 0.910136	valid_1's auc: 0.903562
# [36000]	training's auc: 0.91037	valid_1's auc: 0.90347
# Early stopping, best iteration is:
# [34300]	training's auc: 0.909979	valid_1's auc: 0.903606
# AUC = 0.9036060369719651
#
#
# Fold 4
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.790732	valid_1's auc: 0.785002
# [2000]	training's auc: 0.827438	valid_1's auc: 0.822662
# [3000]	training's auc: 0.847715	valid_1's auc: 0.842284
# [4000]	training's auc: 0.859947	valid_1's auc: 0.853947
# [5000]	training's auc: 0.868412	valid_1's auc: 0.862345
# [6000]	training's auc: 0.874887	valid_1's auc: 0.868656
# [7000]	training's auc: 0.880207	valid_1's auc: 0.87348
# [8000]	training's auc: 0.884745	valid_1's auc: 0.877925
# [9000]	training's auc: 0.888096	valid_1's auc: 0.881011
# [10000]	training's auc: 0.891092	valid_1's auc: 0.883699
# [11000]	training's auc: 0.893454	valid_1's auc: 0.885712
# [12000]	training's auc: 0.895359	valid_1's auc: 0.887386
# [13000]	training's auc: 0.897181	valid_1's auc: 0.888863
# [14000]	training's auc: 0.898723	valid_1's auc: 0.890084
# [15000]	training's auc: 0.900154	valid_1's auc: 0.891338
# [16000]	training's auc: 0.901284	valid_1's auc: 0.892255
# [17000]	training's auc: 0.902348	valid_1's auc: 0.893249
# [18000]	training's auc: 0.903376	valid_1's auc: 0.894109
# [19000]	training's auc: 0.904228	valid_1's auc: 0.894787
# [20000]	training's auc: 0.904989	valid_1's auc: 0.89554
# [21000]	training's auc: 0.9057	valid_1's auc: 0.896035
# [22000]	training's auc: 0.906322	valid_1's auc: 0.896455
# [23000]	training's auc: 0.906879	valid_1's auc: 0.896796
# [24000]	training's auc: 0.907386	valid_1's auc: 0.897192
# [25000]	training's auc: 0.907856	valid_1's auc: 0.897507
# [26000]	training's auc: 0.908297	valid_1's auc: 0.89777
# [27000]	training's auc: 0.908672	valid_1's auc: 0.897927
# [28000]	training's auc: 0.909064	valid_1's auc: 0.898075
# [29000]	training's auc: 0.909379	valid_1's auc: 0.898229
# [30000]	training's auc: 0.909689	valid_1's auc: 0.898461
# [31000]	training's auc: 0.909996	valid_1's auc: 0.898662
# [32000]	training's auc: 0.910282	valid_1's auc: 0.898763
# [33000]	training's auc: 0.910544	valid_1's auc: 0.898879
# [34000]	training's auc: 0.910798	valid_1's auc: 0.898867
# [35000]	training's auc: 0.911025	valid_1's auc: 0.898904
# [36000]	training's auc: 0.911248	valid_1's auc: 0.898992
# [37000]	training's auc: 0.911455	valid_1's auc: 0.899005
# [38000]	training's auc: 0.911665	valid_1's auc: 0.899041
# [39000]	training's auc: 0.911883	valid_1's auc: 0.899017
# Early stopping, best iteration is:
# [37615]	training's auc: 0.911581	valid_1's auc: 0.899086
# AUC = 0.8990855484807364
# Overall AUC = 0.8984628993267338
# 1
#
#
# Fold 0
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.791578	valid_1's auc: 0.788647
# [2000]	training's auc: 0.828004	valid_1's auc: 0.823701
# [3000]	training's auc: 0.846998	valid_1's auc: 0.841836
# [4000]	training's auc: 0.859278	valid_1's auc: 0.85411
# [5000]	training's auc: 0.867774	valid_1's auc: 0.862309
# [6000]	training's auc: 0.874635	valid_1's auc: 0.868971
# [7000]	training's auc: 0.879868	valid_1's auc: 0.874271
# [8000]	training's auc: 0.884264	valid_1's auc: 0.878468
# [9000]	training's auc: 0.887585	valid_1's auc: 0.881655
# [10000]	training's auc: 0.890633	valid_1's auc: 0.88461

# %%
roc_score = roc_auc_score(y_train, all_oof_preds.ravel())
print("Overall AUC = {}".format(roc_score))

# %%
#結果保存
if (submit_flg ==1 and sampling_flg==0):
    series_oof_preds = pd.Series(data=oof_preds[:,0], name=save_col_name, dtype='float')
    series_oof_preds.to_csv(train_preds_dir,header=True, index=False)

    sample = pd.read_csv(sample_submission_dir)
    sample.target = test_preds[:,0].astype(float)
    sample.ID_code = test_df['ID_code']
    sample.to_csv(test_preds_dir, index=False)
