# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

warnings.filterwarnings('ignore')

# %% [markdown]
# 基本変数定義

# %%
sampling_flg=0 #サンプリング有無をコントロール
submit_flg=1 #保存するかをコントロール（サンプリングしない時のみ）

SEED=12345
sample_num=10000
fold_num=5

#train関連
train_dir='../../01_input/train.csv'
train_mean_dir='../../02_feature/122-2_train_mean.csv'
train_drop_col=['ID_code', 'target','mean']
train_label='target'

#test関連
test_dir='../../01_input/test.csv'
test_mean_dir='../../02_feature/122-2_test_mean.csv'
test_drop_col=['ID_code','mean']

#予測結果
pred_test_dir='../../04_predict_test/oka_252-2_LightGBM_submission.csv'
pred_train_dir='../../03_predict_train/oka_252-2_LightGBM_train.csv'

#結果ファイル関連　nameは自分の名前に変更する
train_preds_dir='../../03_predict_train/oka_252-3_LightGBM_train.csv'
test_preds_dir='../../04_predict_test/oka_252-3_LightGBM_submission.csv'
save_col_name='oof_xgb'

sample_submission_dir='../../01_input/sample_submission.csv'
submission_target_col_name='target'
submission_id_col_name='ID_code'

# %% [markdown]
# 前処理

# %%
#ロード
train_df=pd.read_csv(train_dir)
test_df=pd.read_csv(test_dir)
train_mean_df=pd.read_csv(train_mean_dir,header=None,index_col=0)
test_mean_df=pd.read_csv(test_mean_dir,header=None,index_col=0)

pred_train_df = pd.read_csv(pred_train_dir)
pred_test_df = pd.read_csv(pred_test_dir)

# %%
pred_train_df.head()
# Out:
#     oof_xgb
# 0  0.032594
# 1  0.422843
# 2  0.014319
# 3  0.233246
# 4  0.095201

# %%
train_df['mean']=train_mean_df
test_df['mean']=test_mean_df

# %%
train_df_0=train_df[train_df['mean'] <  0.5]
train_df_1=train_df[train_df['mean'] >= 0.5]
test_df_0=test_df[test_df['mean'] <  0.5]
test_df_1=test_df[test_df['mean'] >= 0.5]

# %%
len(train_df_1),len(test_df_1)
# Out:
# (23553, 20979)

# %%
len(train_df_0),len(test_df_0)
# Out:
# (176447, 179021)

# %%
#x,y作成
x_train_0=train_df_0.drop(train_drop_col,axis=1)
y_train_0=train_df_0[train_label]
x_test_0=test_df_0.drop(test_drop_col,axis=1)

x_train_1=train_df_1.drop(train_drop_col,axis=1)
y_train_1=train_df_1[train_label]
x_test_1=test_df_1.drop(test_drop_col,axis=1)

x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]

# %%
#ベースライン
print("AUC = {}".format(roc_auc_score(y_train, pred_train_df)))
print(confusion_matrix(y_train, pd.DataFrame(np.round(pred_train_df))))
# Out:
# AUC = 0.887815127880921
# [[177973   1929]
#  [ 13225   6873]]

# %%
#ベースライン
print("AUC = {}".format(roc_auc_score(y_train, train_mean_df)))
print(confusion_matrix(y_train, pd.DataFrame(np.round(train_mean_df))))
# Out:
# AUC = 0.900925089190569
# [[168847  11055]
#  [  7600  12498]]

# %%
# Out:
# "\nnew_pred_train=pd.DataFrame()\nnew_train=pd.DataFrame()\n\nnew_pred_train=train_df_0['ID_code']\nnew_pred_train=pd.concat([new_pred_train,train_df_0['mean']],axis=1)\nnew_pred_train['ID_code']=new_pred_train['ID_code'].astype('object')\n\nnew_train['target']=y_train\nnew_train=pd.concat([new_train,train_df['ID_code']],axis=1)\nnew_train['ID_code']=new_train['ID_code'].astype('object')\n\nprint(new_train.describe())\nprint(new_pred_train.describe())\nnew_train=pd.merge(new_train, new_pred_train, how='left', on='ID_code')\nnew_train=pd.concat([new_train,x_train],axis=1)\n\nnew_train.head()\n"

# %% [markdown]
# モデル実行

# %%
#ベースライン
print("AUC = {}".format(roc_auc_score(y_train_0, pd.DataFrame(train_df_0['mean']))))
print(confusion_matrix(y_train_0, pd.DataFrame(np.round(train_df_0['mean']))))
# Out:
# AUC = 0.8132500546274687
# [[168847      0]
#  [  7600      0]]

# %%
#model_param
param = {
    "objective" : "binary", 
    "boost":"gbdt",
    "metric":"auc",
    "boost_from_average":"false",
    "num_threads":28,
    "learning_rate" : 0.01,
    "num_leaves" : 13,
    "max_depth":-1,
    "tree_learner" : "serial",
    "feature_fraction" : 0.05,
    "bagging_freq" : 5,
    "bagging_fraction" : 0.4,
    "min_data_in_leaf" : 80,
    "min_sum_hessian_in_leaf" : 10.0,
    "verbosity" : 1,
    'seed': 44000,
    }

# %%
folds = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=SEED)
oof_preds = np.zeros((len(x_train_0), 1))
test_preds = np.zeros((len(x_test_0), 1))

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train_0.values, y_train_0.values)):
    print("\n")
    print("Fold {}".format(fold_))
    trn_x,trn_y = x_train_0.iloc[trn_idx], y_train_0.iloc[trn_idx]
    val_x,val_y = x_train_0.iloc[val_idx], y_train_0.iloc[val_idx]
    trn_data = lgb.Dataset(trn_x,trn_y)
    val_data = lgb.Dataset(val_x,val_y)
    
    num_round = 1000000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 1000)
    val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
    test_pred = clf.predict(x_test_0, num_iteration=clf.best_iteration)
    
    print("AUC = {}".format(roc_auc_score(val_y, pd.DataFrame(val_pred))))
    #print("val = {}".format(val_pred)
    oof_preds[val_idx, :] = val_pred.reshape((-1, 1))
    test_preds += test_pred.reshape((-1, 1))
    
    print(confusion_matrix(val_y, pd.DataFrame(np.round(val_pred))))
    
test_preds /= fold_num
roc_score = roc_auc_score(y_train_0, pd.DataFrame(oof_preds.ravel()))
print("Overall AUC = {}".format(roc_score))
print(confusion_matrix(y_train_0, pd.DataFrame(np.round(oof_preds))))
# Out:
# Fold 0
# Training until validation scores don't improve for 1000 rounds.
# [1000]	training's auc: 0.90329	valid_1's auc: 0.770944
# [2000]	training's auc: 0.923424	valid_1's auc: 0.785547
# [3000]	training's auc: 0.936173	valid_1's auc: 0.790419
# [4000]	training's auc: 0.945745	valid_1's auc: 0.794136
# [5000]	training's auc: 0.953686	valid_1's auc: 0.795884
# [6000]	training's auc: 0.960491	valid_1's auc: 0.796433
# [7000]	training's auc: 0.966296	valid_1's auc: 0.796161
# Early stopping, best iteration is:
# [6194]	training's auc: 0.961628	valid_1's auc: 0.796732
# AUC = 0.7967316833689199
# [[33770     0]
#  [ 1520     0]]
#
#
# Fold 1
# Training until validation scores don't improve for 1000 rounds.
# [1000]	training's auc: 0.899979	valid_1's auc: 0.781675
# [2000]	training's auc: 0.920656	valid_1's auc: 0.795968
# [3000]	training's auc: 0.934289	valid_1's auc: 0.802065
# [4000]	training's auc: 0.944122	valid_1's auc: 0.80366
# [5000]	training's auc: 0.952508	valid_1's auc: 0.805559
# [6000]	training's auc: 0.959207	valid_1's auc: 0.807262
# [7000]	training's auc: 0.964798	valid_1's auc: 0.807899
# [8000]	training's auc: 0.970147	valid_1's auc: 0.808221
# [9000]	training's auc: 0.974806	valid_1's auc: 0.808286
# Early stopping, best iteration is:
# [8535]	training's auc: 0.972711	valid_1's auc: 0.808712
# AUC = 0.8087117185917118
# [[33770     0]
#  [ 1520     0]]
#
#
# Fold 2
# Training until validation scores don't improve for 1000 rounds.
# [1000]	training's auc: 0.902542	valid_1's auc: 0.769921
# [2000]	training's auc: 0.922126	valid_1's auc: 0.784191
# [3000]	training's auc: 0.935447	valid_1's auc: 0.790103
# [4000]	training's auc: 0.945212	valid_1's auc: 0.792995
# [5000]	training's auc: 0.95303	valid_1's auc: 0.793905
# [6000]	training's auc: 0.959534	valid_1's auc: 0.795389
# [7000]	training's auc: 0.965372	valid_1's auc: 0.796025
# [8000]	training's auc: 0.970494	valid_1's auc: 0.796879
# Early stopping, best iteration is:
# [7990]	training's auc: 0.970442	valid_1's auc: 0.796899
# AUC = 0.7968989972117062
# [[33769     0]
#  [ 1520     0]]
#
#
# Fold 3
# Training until validation scores don't improve for 1000 rounds.
# [1000]	training's auc: 0.90078	valid_1's auc: 0.757294
# [2000]	training's auc: 0.922953	valid_1's auc: 0.775766
# [3000]	training's auc: 0.936163	valid_1's auc: 0.78203
# [4000]	training's auc: 0.945537	valid_1's auc: 0.782948
# [5000]	training's auc: 0.953317	valid_1's auc: 0.785231
# [6000]	training's auc: 0.959993	valid_1's auc: 0.785812
# Early stopping, best iteration is:
# [5349]	training's auc: 0.955879	valid_1's auc: 0.786312
# AUC = 0.7863124424300707
# [[33769     0]
#  [ 1520     0]]
#
#
# Fold 4
# Training until validation scores don't improve for 1000 rounds.
# [1000]	training's auc: 0.901894	valid_1's auc: 0.756347
# [2000]	training's auc: 0.923065	valid_1's auc: 0.772054
# [3000]	training's auc: 0.935894	valid_1's auc: 0.778817
# [4000]	training's auc: 0.945087	valid_1's auc: 0.782333
# [5000]	training's auc: 0.952777	valid_1's auc: 0.784335
# [6000]	training's auc: 0.959621	valid_1's auc: 0.78646
# [7000]	training's auc: 0.965373	valid_1's auc: 0.78745
# [8000]	training's auc: 0.970359	valid_1's auc: 0.788146
# [9000]	training's auc: 0.974888	valid_1's auc: 0.788309
# [10000]	training's auc: 0.97897	valid_1's auc: 0.788668
# [11000]	training's auc: 0.982417	valid_1's auc: 0.788428
# Early stopping, best iteration is:
# [10067]	training's auc: 0.979207	valid_1's auc: 0.788798
# AUC = 0.7887979827340864
# [[33769     0]
#  [ 1520     0]]
# Overall AUC = 0.7946585923475409
# [[168847      0]
#  [  7600      0]]

# %%
base=pd.DataFrame(train_df_0['mean'])
base=base.reset_index(drop=True)
new=pd.DataFrame(oof_preds)
new=new.reset_index(drop=True)
y_train_0=y_train_0.reset_index(drop=True)

diff=pd.DataFrame()
diff=pd.concat([base,new],axis=1)
diff['label']=y_train_0
len(base),len(new),len(y_train_0),len(diff)
# Out:
# (176447, 176447, 176447, 176447)

# %%
diff
# Out:
#             mean         0  label
# 0       0.036122  0.015763      0
# 1       0.023994  0.008886      0
# 2       0.491483  0.257509      0
# 3       0.258872  0.110139      0
# 4       0.081136  0.031916      0
# 5       0.293005  0.065244      0
# 6       0.199532  0.050436      0
# 7       0.245156  0.058438      0
# 8       0.046868  0.015661      0
# 9       0.034361  0.007665      0
# 10      0.160050  0.085835      0
# 11      0.057552  0.025762      0
# 12      0.246991  0.036176      0
# 13      0.430913  0.158285      0
# 14      0.019796  0.012532      0
# 15      0.046668  0.015623      0
# 16      0.208805  0.032699      0
# 17      0.041823  0.014732      0
# 18      0.100759  0.029047      0
# 19      0.066291  0.016690      0
# 20      0.170120  0.043593      0
# 21      0.159772  0.042680      0
# 22      0.097771  0.041779      0
# 23      0.046409  0.021064      0
# 24      0.286883  0.074053      0
# 25      0.051473  0.016650      0
# 26      0.020025  0.011289      0
# 27      0.402821  0.100846      1
# 28      0.151081  0.048851      0
# 29      0.082884  0.016344      0
# ...          ...       ...    ...
# 176417  0.122585  0.043103      0
# 176418  0.109710  0.021431      0
# 176419  0.083006  0.027632      0
# 176420  0.252129  0.094605      0
# 176421  0.006926  0.002990      0
# 176422  0.040192  0.008772      0
# 176423  0.075813  0.036433      0
# 176424  0.265880  0.068999      0
# 176425  0.057434  0.024402      0
# 176426  0.184352  0.089634      0
# 176427  0.018517  0.010179      0
# 176428  0.099265  0.030749      1
# 176429  0.036177  0.017633      0
# 176430  0.095892  0.032437      0
# 176431  0.066691  0.017040      0
# 176432  0.033175  0.009203      0
# 176433  0.048988  0.025577      0
# 176434  0.037437  0.013968      0
# 176435  0.014881  0.009608      0
# 176436  0.018426  0.007144      0
# 176437  0.035264  0.013758      0
# 176438  0.423803  0.122067      1
# 176439  0.043721  0.014815      0
# 176440  0.100685  0.038250      0
# 176441  0.021896  0.008477      0
# 176442  0.225038  0.045961      0
# 176443  0.156848  0.038025      0
# 176444  0.160594  0.048304      0
# 176445  0.189798  0.062898      0
# 176446  0.029257  0.012710      0
#
# [176447 rows x 3 columns]

# %%
print("Overall AUC = {}".format(roc_auc_score(y_train_0, base)))
print(confusion_matrix(y_train_0, pd.DataFrame(np.round(base))))
print("Overall AUC = {}".format(roc_auc_score(y_train_0, new)))
print(confusion_matrix(y_train_0, pd.DataFrame(np.round(new))))
# Out:
# Overall AUC = 0.8132500546274687
# [[168847      0]
#  [  7600      0]]
# Overall AUC = 0.7946585923475409
# [[168847      0]
#  [  7600      0]]

# %%
#ベースライン
print("AUC = {}".format(roc_auc_score(y_train_1, train_df_1['mean'])))
print(confusion_matrix(y_train_1, pd.DataFrame(np.round(train_df_1['mean']))))
# Out:
# AUC = 0.7498668443667404
# [[    0 11055]
#  [    0 12498]]

# %%
#model_param
param = {
    "objective" : "binary", 
    "boost":"gbdt",
    "metric":"auc",
    "boost_from_average":"false",
    "num_threads":28,
    "learning_rate" : 0.01,
    "num_leaves" : 13,
    "max_depth":2,
    "tree_learner" : "serial",
    "feature_fraction" : 0.05,
    "bagging_freq" : 5,
    "bagging_fraction" : 0.4,
    "min_data_in_leaf" : 80,
    "min_sum_hessian_in_leaf" : 10.0,
    "verbosity" : 1,
    'seed': 44000,
    }

# %%
folds = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=1)
oof_preds = np.zeros((len(x_train_1), 1))
test_preds = np.zeros((len(x_test_1), 1))

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train_1.values, y_train_1.values)):
    print("\n")
    print("Fold {}".format(fold_))
    trn_x,trn_y = x_train_1.iloc[trn_idx], y_train_1.iloc[trn_idx]
    val_x,val_y = x_train_1.iloc[val_idx], y_train_1.iloc[val_idx]
    trn_data = lgb.Dataset(trn_x,trn_y)
    val_data = lgb.Dataset(val_x,val_y)
    
    num_round = 1000000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 3000)
    val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
    test_pred = clf.predict(x_test_1, num_iteration=clf.best_iteration)
    
    print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
    #print("val = {}".format(val_pred)
    oof_preds[val_idx, :] = val_pred.reshape((-1, 1))
    test_preds += test_pred.reshape((-1, 1))
    
    print(confusion_matrix(val_y, pd.DataFrame(np.round(val_pred))))
    
test_preds /= fold_num
roc_score = roc_auc_score(y_train_1, oof_preds.ravel())
print("Overall AUC = {}".format(roc_score))
print(confusion_matrix(y_train_1, pd.DataFrame(np.round(oof_preds))))
# Out:
# Fold 0
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.776765	valid_1's auc: 0.655143
# [2000]	training's auc: 0.80197	valid_1's auc: 0.669496
# [3000]	training's auc: 0.821347	valid_1's auc: 0.680055
# [4000]	training's auc: 0.835698	valid_1's auc: 0.686815
# [5000]	training's auc: 0.8471	valid_1's auc: 0.695493
# [6000]	training's auc: 0.855692	valid_1's auc: 0.699679
# [7000]	training's auc: 0.863847	valid_1's auc: 0.704073
# [8000]	training's auc: 0.869592	valid_1's auc: 0.70517
# [9000]	training's auc: 0.875205	valid_1's auc: 0.706953
# [10000]	training's auc: 0.881286	valid_1's auc: 0.709052
# [11000]	training's auc: 0.886112	valid_1's auc: 0.710611
# [12000]	training's auc: 0.890662	valid_1's auc: 0.712268
# [13000]	training's auc: 0.894725	valid_1's auc: 0.713312
# [14000]	training's auc: 0.898526	valid_1's auc: 0.714733
# [15000]	training's auc: 0.901961	valid_1's auc: 0.71573
# [16000]	training's auc: 0.905916	valid_1's auc: 0.717226
# [17000]	training's auc: 0.909251	valid_1's auc: 0.717351
# [18000]	training's auc: 0.912168	valid_1's auc: 0.718366
# [19000]	training's auc: 0.915121	valid_1's auc: 0.718387
# [20000]	training's auc: 0.91798	valid_1's auc: 0.718682
# [21000]	training's auc: 0.920892	valid_1's auc: 0.718843
# [22000]	training's auc: 0.923714	valid_1's auc: 0.719367
# [23000]	training's auc: 0.926642	valid_1's auc: 0.720056
# [24000]	training's auc: 0.92918	valid_1's auc: 0.720211
# [25000]	training's auc: 0.931705	valid_1's auc: 0.72037
# [26000]	training's auc: 0.934196	valid_1's auc: 0.720412
# [27000]	training's auc: 0.936492	valid_1's auc: 0.720253
# [28000]	training's auc: 0.93872	valid_1's auc: 0.720996
# [29000]	training's auc: 0.941024	valid_1's auc: 0.721267
# [30000]	training's auc: 0.943164	valid_1's auc: 0.72172
# [31000]	training's auc: 0.9451	valid_1's auc: 0.721962
# [32000]	training's auc: 0.947142	valid_1's auc: 0.722152
# [33000]	training's auc: 0.949114	valid_1's auc: 0.722468
# [34000]	training's auc: 0.950993	valid_1's auc: 0.722509
# [35000]	training's auc: 0.952853	valid_1's auc: 0.722185
# [36000]	training's auc: 0.954604	valid_1's auc: 0.72203
# Early stopping, best iteration is:
# [33910]	training's auc: 0.950838	valid_1's auc: 0.722657
# AUC = 0.7226570782451379
# [[1463  748]
#  [ 850 1650]]
#
#
# Fold 1
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.774553	valid_1's auc: 0.636837
# [2000]	training's auc: 0.801618	valid_1's auc: 0.648645
# [3000]	training's auc: 0.820255	valid_1's auc: 0.660477
# [4000]	training's auc: 0.834829	valid_1's auc: 0.670725
# [5000]	training's auc: 0.845746	valid_1's auc: 0.676079
# [6000]	training's auc: 0.854605	valid_1's auc: 0.68026
# [7000]	training's auc: 0.863005	valid_1's auc: 0.685533
# [8000]	training's auc: 0.86953	valid_1's auc: 0.689158
# [9000]	training's auc: 0.875426	valid_1's auc: 0.692306
# [10000]	training's auc: 0.88085	valid_1's auc: 0.694123
# [11000]	training's auc: 0.886111	valid_1's auc: 0.69678
# [12000]	training's auc: 0.891016	valid_1's auc: 0.698161
# [13000]	training's auc: 0.895283	valid_1's auc: 0.698626
# [14000]	training's auc: 0.899339	valid_1's auc: 0.700612
# [15000]	training's auc: 0.903178	valid_1's auc: 0.701707
# [16000]	training's auc: 0.906695	valid_1's auc: 0.702098
# [17000]	training's auc: 0.909988	valid_1's auc: 0.703249
# [18000]	training's auc: 0.91313	valid_1's auc: 0.704079
# [19000]	training's auc: 0.916136	valid_1's auc: 0.704895
# [20000]	training's auc: 0.9191	valid_1's auc: 0.705151
# [21000]	training's auc: 0.921818	valid_1's auc: 0.705195
# [22000]	training's auc: 0.92468	valid_1's auc: 0.706035
# [23000]	training's auc: 0.927284	valid_1's auc: 0.706095
# [24000]	training's auc: 0.929792	valid_1's auc: 0.706318
# [25000]	training's auc: 0.932043	valid_1's auc: 0.706654
# [26000]	training's auc: 0.934762	valid_1's auc: 0.706997
# [27000]	training's auc: 0.937167	valid_1's auc: 0.707527
# [28000]	training's auc: 0.939322	valid_1's auc: 0.707723
# [29000]	training's auc: 0.941412	valid_1's auc: 0.708617
# [30000]	training's auc: 0.943563	valid_1's auc: 0.708518
# [31000]	training's auc: 0.945521	valid_1's auc: 0.708361
# [32000]	training's auc: 0.947365	valid_1's auc: 0.708519
# Early stopping, best iteration is:
# [29255]	training's auc: 0.94195	valid_1's auc: 0.708817
# AUC = 0.7088173677069199
# [[1429  782]
#  [ 843 1657]]
#
#
# Fold 2
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.783422	valid_1's auc: 0.656279
# [2000]	training's auc: 0.809812	valid_1's auc: 0.67499
# [3000]	training's auc: 0.82368	valid_1's auc: 0.681782
# [4000]	training's auc: 0.837799	valid_1's auc: 0.688531
# [5000]	training's auc: 0.848291	valid_1's auc: 0.693716
# [6000]	training's auc: 0.856811	valid_1's auc: 0.698581
# [7000]	training's auc: 0.865208	valid_1's auc: 0.703551
# [8000]	training's auc: 0.871233	valid_1's auc: 0.706949
# [9000]	training's auc: 0.876376	valid_1's auc: 0.708439
# [10000]	training's auc: 0.881338	valid_1's auc: 0.709475
# [11000]	training's auc: 0.886361	valid_1's auc: 0.71
# [12000]	training's auc: 0.890905	valid_1's auc: 0.71085
# [13000]	training's auc: 0.895265	valid_1's auc: 0.71241
# [14000]	training's auc: 0.899141	valid_1's auc: 0.713269
# [15000]	training's auc: 0.90272	valid_1's auc: 0.71551
# [16000]	training's auc: 0.906418	valid_1's auc: 0.71602
# [17000]	training's auc: 0.909874	valid_1's auc: 0.717172
# [18000]	training's auc: 0.91321	valid_1's auc: 0.717752
# [19000]	training's auc: 0.916085	valid_1's auc: 0.718754
# [20000]	training's auc: 0.919342	valid_1's auc: 0.718693
# [21000]	training's auc: 0.9222	valid_1's auc: 0.718963
# [22000]	training's auc: 0.924963	valid_1's auc: 0.719197
# [23000]	training's auc: 0.927483	valid_1's auc: 0.719197
# [24000]	training's auc: 0.929942	valid_1's auc: 0.719549
# [25000]	training's auc: 0.932474	valid_1's auc: 0.72012
# [26000]	training's auc: 0.934873	valid_1's auc: 0.720124
# [27000]	training's auc: 0.937267	valid_1's auc: 0.72018
# [28000]	training's auc: 0.939393	valid_1's auc: 0.719985
# Early stopping, best iteration is:
# [25310]	training's auc: 0.933292	valid_1's auc: 0.72049
# AUC = 0.7204899140660335
# [[1431  780]
#  [ 822 1678]]
#
#
# Fold 3
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.777712	valid_1's auc: 0.644629
# [2000]	training's auc: 0.806639	valid_1's auc: 0.66554
# [3000]	training's auc: 0.822215	valid_1's auc: 0.674705
# [4000]	training's auc: 0.836891	valid_1's auc: 0.683825
# [5000]	training's auc: 0.848026	valid_1's auc: 0.688739
# [6000]	training's auc: 0.856958	valid_1's auc: 0.692979
# [7000]	training's auc: 0.86482	valid_1's auc: 0.696741
# [8000]	training's auc: 0.87101	valid_1's auc: 0.701193
# [9000]	training's auc: 0.87675	valid_1's auc: 0.703495
# [10000]	training's auc: 0.882271	valid_1's auc: 0.705597
# [11000]	training's auc: 0.887247	valid_1's auc: 0.707641
# [12000]	training's auc: 0.891095	valid_1's auc: 0.708849
# [13000]	training's auc: 0.895179	valid_1's auc: 0.710466
# [14000]	training's auc: 0.898809	valid_1's auc: 0.711883
# [15000]	training's auc: 0.902782	valid_1's auc: 0.713129
# [16000]	training's auc: 0.906378	valid_1's auc: 0.714505
# [17000]	training's auc: 0.909928	valid_1's auc: 0.715828
# [18000]	training's auc: 0.913241	valid_1's auc: 0.7161
# [19000]	training's auc: 0.91641	valid_1's auc: 0.716091
# [20000]	training's auc: 0.919127	valid_1's auc: 0.717045
# [21000]	training's auc: 0.922067	valid_1's auc: 0.717301
# [22000]	training's auc: 0.924735	valid_1's auc: 0.718004
# [23000]	training's auc: 0.927607	valid_1's auc: 0.718773
# [24000]	training's auc: 0.930058	valid_1's auc: 0.719094
# [25000]	training's auc: 0.932557	valid_1's auc: 0.719272
# [26000]	training's auc: 0.935037	valid_1's auc: 0.718939
# [27000]	training's auc: 0.937254	valid_1's auc: 0.719062
# [28000]	training's auc: 0.939334	valid_1's auc: 0.719163
# [29000]	training's auc: 0.941459	valid_1's auc: 0.718986
# [30000]	training's auc: 0.943551	valid_1's auc: 0.719236
# Early stopping, best iteration is:
# [27446]	training's auc: 0.938183	valid_1's auc: 0.719487
# AUC = 0.7194868901880064
# [[1450  761]
#  [ 828 1671]]
#
#
# Fold 4
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.778242	valid_1's auc: 0.648531
# [2000]	training's auc: 0.805987	valid_1's auc: 0.664441
# [3000]	training's auc: 0.822095	valid_1's auc: 0.6744
# [4000]	training's auc: 0.83643	valid_1's auc: 0.681972
# [5000]	training's auc: 0.848158	valid_1's auc: 0.687447
# [6000]	training's auc: 0.856548	valid_1's auc: 0.692187
# [7000]	training's auc: 0.864268	valid_1's auc: 0.695016
# [8000]	training's auc: 0.870768	valid_1's auc: 0.698122
# [9000]	training's auc: 0.876415	valid_1's auc: 0.70064
# [10000]	training's auc: 0.881903	valid_1's auc: 0.703692
# [11000]	training's auc: 0.886974	valid_1's auc: 0.704937
# [12000]	training's auc: 0.891307	valid_1's auc: 0.705946
# [13000]	training's auc: 0.89513	valid_1's auc: 0.70594
# [14000]	training's auc: 0.898805	valid_1's auc: 0.70689
# [15000]	training's auc: 0.902539	valid_1's auc: 0.707743
# [16000]	training's auc: 0.906115	valid_1's auc: 0.708712
# [17000]	training's auc: 0.909463	valid_1's auc: 0.710394
# [18000]	training's auc: 0.912595	valid_1's auc: 0.711265
# [19000]	training's auc: 0.915801	valid_1's auc: 0.711578
# [20000]	training's auc: 0.918754	valid_1's auc: 0.712852
# [21000]	training's auc: 0.921587	valid_1's auc: 0.712595
# [22000]	training's auc: 0.924203	valid_1's auc: 0.713064
# [23000]	training's auc: 0.927127	valid_1's auc: 0.712656
# [24000]	training's auc: 0.929774	valid_1's auc: 0.712173
# [25000]	training's auc: 0.93219	valid_1's auc: 0.712255
# Early stopping, best iteration is:
# [22072]	training's auc: 0.92446	valid_1's auc: 0.713208
# AUC = 0.7132081235931731
# [[1420  791]
#  [ 864 1635]]
# Overall AUC = 0.7168925589831144
# [[7193 3862]
#  [4207 8291]]

# %%
#結果保存
if (submit_flg ==1 and sampling_flg==0):
    sample = pd.read_csv(sample_submission_dir)
    sample.target = test_mean_df
    sample.ID_code = test_df['ID_code']
    sample.to_csv(test_preds_dir, index=False)

# %%
new_pred_train=pd.DataFrame()
new_train=pd.DataFrame()

new_pred_train=train_df_0['ID_code']
new_pred_train=pd.concat([new_pred_train,train_df_0['mean']],axis=1)
new_pred_train['ID_code']=new_pred_train['ID_code'].astype('object')

new_train['target']=y_train
new_train=pd.concat([new_train,train_df['ID_code']],axis=1)
new_train['ID_code']=new_train['ID_code'].astype('object')

print(new_train.describe())
print(new_pred_train.describe())
new_train=pd.merge(new_train, new_pred_train, how='left', on='ID_code')
new_train=pd.concat([new_train,x_train],axis=1)

new_train.head()
