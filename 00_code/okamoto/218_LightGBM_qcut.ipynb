# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit

from sklearn.model_selection import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV

warnings.filterwarnings('ignore')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# 基本変数定義

# %%
sampling_flg=0 #サンプリング有無をコントロール
submit_flg=1 #保存するかをコントロール（サンプリングしない時のみ）

SEED=12345
sample_num=10000
fold_num=5

#train関連
train_dir='../../02_feature/113_train_qcut.csv'
train_drop_col=['ID_code', 'target']
train_label='target'

#test関連
test_dir='../../02_feature/113_test_qcut.csv'
test_drop_col=['ID_code']

#結果ファイル関連　nameは自分の名前に変更する
train_preds_dir='../../03_predict_train/oka_218_LightGBM_qcut_train.csv'
test_preds_dir='../../04_predict_test/oka_218_LightGBM_qcut_submission.csv'
save_col_name='oof_xgb'

sample_submission_dir='../../01_input/sample_submission.csv'
submission_target_col_name='target'
submission_id_col_name='ID_code'

# %% [markdown]
# 前処理

# %%
#ロード
train_df=pd.read_csv(train_dir)
test_df=pd.read_csv(test_dir)

# %%
#サンプリング
if sampling_flg ==1:
    train_df=train_df.sample(n=sample_num,random_state=SEED)
    test_df=test_df.sample(n=sample_num,random_state=SEED)

# %%
#x,y作成
x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]
x_test=test_df.drop(test_drop_col,axis=1)

# %% [markdown]
# モデル実行

# %%
#model_param
param = {
        'num_leaves': 2,
        'max_bin': 63,
        'min_data_in_leaf': 45,
        'learning_rate': 0.01,
        'min_sum_hessian_in_leaf': 0.000446,
        'bagging_fraction': 0.55, 
        'bagging_freq': 5, 
        'max_depth': 14,
        'save_binary': True,
        'seed': 31452,
        'feature_fraction_seed': 31415,
        'feature_fraction': 0.51,
        'bagging_seed': 31415,
        'drop_seed': 31415,
        'data_random_seed': 31415,
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': 1,
        'metric': 'auc',
        'is_unbalance': True,
        'boost_from_average': False,
    }

# %%
folds = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=SEED)
oof_preds = np.zeros((len(x_train), 1))
test_preds = np.zeros((len(x_test), 1))

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train.values, y_train.values)):
    print("\n")
    print("Fold {}".format(fold_))
    trn_x,trn_y = x_train.iloc[trn_idx], y_train.iloc[trn_idx]
    val_x,val_y = x_train.iloc[val_idx], y_train.iloc[val_idx]
    trn_data = lgb.Dataset(trn_x,trn_y)
    val_data = lgb.Dataset(val_x,val_y)
    
    num_round = 50000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 2000)
    val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
    test_pred = clf.predict(x_test, num_iteration=clf.best_iteration)
    
    print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
    #print("val = {}".format(val_pred)
    oof_preds[val_idx, :] = val_pred.reshape((-1, 1))
    test_preds += test_pred.reshape((-1, 1))
    
test_preds /= fold_num
roc_score = roc_auc_score(y_train, oof_preds.ravel())
print("Overall AUC = {}".format(roc_score))
# Out:
# Fold 0
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.791293	valid_1's auc: 0.786103
# [2000]	training's auc: 0.827794	valid_1's auc: 0.823577
# [3000]	training's auc: 0.847561	valid_1's auc: 0.843215
# [4000]	training's auc: 0.859268	valid_1's auc: 0.854495
# [5000]	training's auc: 0.868616	valid_1's auc: 0.863182
# [6000]	training's auc: 0.875614	valid_1's auc: 0.869505
# [7000]	training's auc: 0.880959	valid_1's auc: 0.874179
# [8000]	training's auc: 0.884844	valid_1's auc: 0.877496
# [16000]	training's auc: 0.901618	valid_1's auc: 0.8909
# [17000]	training's auc: 0.902706	valid_1's auc: 0.891804
# [18000]	training's auc: 0.903732	valid_1's auc: 0.892633
# [19000]	training's auc: 0.904593	valid_1's auc: 0.893447
# [20000]	training's auc: 0.905402	valid_1's auc: 0.894128
# [21000]	training's auc: 0.906092	valid_1's auc: 0.894566
# [22000]	training's auc: 0.906709	valid_1's auc: 0.895094
# [23000]	training's auc: 0.907262	valid_1's auc: 0.895435
# [24000]	training's auc: 0.907792	valid_1's auc: 0.895898
# [25000]	training's auc: 0.908287	valid_1's auc: 0.896214
# [26000]	training's auc: 0.9087	valid_1's auc: 0.896493
# [27000]	training's auc: 0.909073	valid_1's auc: 0.896714
# [28000]	training's auc: 0.909449	valid_1's auc: 0.896932
# [29000]	training's auc: 0.909815	valid_1's auc: 0.897103
# [30000]	training's auc: 0.910164	valid_1's auc: 0.897237
# [31000]	training's auc: 0.910444	valid_1's auc: 0.897337
# [32000]	training's auc: 0.910739	valid_1's auc: 0.897446
# [33000]	training's auc: 0.911012	valid_1's auc: 0.897558
# [34000]	training's auc: 0.911236	valid_1's auc: 0.897691
# [35000]	training's auc: 0.911486	valid_1's auc: 0.897705
# [36000]	training's auc: 0.911714	valid_1's auc: 0.897744
# [37000]	training's auc: 0.911918	valid_1's auc: 0.897793
# [38000]	training's auc: 0.912121	valid_1's auc: 0.897794
# [39000]	training's auc: 0.912337	valid_1's auc: 0.897818
# [40000]	training's auc: 0.912521	valid_1's auc: 0.897764
# [41000]	training's auc: 0.912713	valid_1's auc: 0.897812
# [42000]	training's auc: 0.912909	valid_1's auc: 0.897793
# Early stopping, best iteration is:
# [40862]	training's auc: 0.912693	valid_1's auc: 0.897828
# AUC = 0.8978277507158628
#
#
# Fold 2
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.790702	valid_1's auc: 0.78477
# [2000]	training's auc: 0.828537	valid_1's auc: 0.819739
# [3000]	training's auc: 0.848694	valid_1's auc: 0.839091
# [4000]	training's auc: 0.861099	valid_1's auc: 0.851127
# [5000]	training's auc: 0.869638	valid_1's auc: 0.858827
# [6000]	training's auc: 0.876078	valid_1's auc: 0.864826
# [7000]	training's auc: 0.881278	valid_1's auc: 0.869726
# [8000]	training's auc: 0.885325	valid_1's auc: 0.873754
# [9000]	training's auc: 0.888568	valid_1's auc: 0.876754
# [10000]	training's auc: 0.89142	valid_1's auc: 0.879403
# [11000]	training's auc: 0.893824	valid_1's auc: 0.881347
# [12000]	training's auc: 0.895967	valid_1's auc: 0.883516
# [13000]	training's auc: 0.897616	valid_1's auc: 0.88513
# [14000]	training's auc: 0.899148	valid_1's auc: 0.886507
# [15000]	training's auc: 0.900506	valid_1's auc: 0.887733
# [16000]	training's auc: 0.901777	valid_1's auc: 0.888818
# [17000]	training's auc: 0.902874	valid_1's auc: 0.889804
# [18000]	training's auc: 0.903855	valid_1's auc: 0.890626
# [19000]	training's auc: 0.904774	valid_1's auc: 0.891486
# [20000]	training's auc: 0.905571	valid_1's auc: 0.89214
# [21000]	training's auc: 0.906242	valid_1's auc: 0.892756
# [22000]	training's auc: 0.906903	valid_1's auc: 0.893331
# [23000]	training's auc: 0.907459	valid_1's auc: 0.893688
# [24000]	training's auc: 0.907982	valid_1's auc: 0.893948
# [25000]	training's auc: 0.908506	valid_1's auc: 0.894376
# [26000]	training's auc: 0.908936	valid_1's auc: 0.894634
# [27000]	training's auc: 0.909317	valid_1's auc: 0.89492
# [28000]	training's auc: 0.90967	valid_1's auc: 0.895139
# [29000]	training's auc: 0.910001	valid_1's auc: 0.895294
# [30000]	training's auc: 0.910301	valid_1's auc: 0.89561
# [31000]	training's auc: 0.910617	valid_1's auc: 0.895829
# [32000]	training's auc: 0.910898	valid_1's auc: 0.896053
# [33000]	training's auc: 0.911148	valid_1's auc: 0.896138
# [34000]	training's auc: 0.911386	valid_1's auc: 0.896287
# [35000]	training's auc: 0.911605	valid_1's auc: 0.896393
# [36000]	training's auc: 0.911845	valid_1's auc: 0.896438
# [37000]	training's auc: 0.912066	valid_1's auc: 0.896457
# [38000]	training's auc: 0.912261	valid_1's auc: 0.89652
# [39000]	training's auc: 0.912465	valid_1's auc: 0.89646
# Early stopping, best iteration is:
# [37820]	training's auc: 0.912225	valid_1's auc: 0.896537
# AUC = 0.8965367990508825
#
#
# Fold 3
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.790354	valid_1's auc: 0.786591
# [2000]	training's auc: 0.828354	valid_1's auc: 0.82355
# [3000]	training's auc: 0.847982	valid_1's auc: 0.842114
# [4000]	training's auc: 0.860091	valid_1's auc: 0.853328
# [5000]	training's auc: 0.868664	valid_1's auc: 0.861195
# [6000]	training's auc: 0.875322	valid_1's auc: 0.86738
# [7000]	training's auc: 0.880546	valid_1's auc: 0.872145
# [8000]	training's auc: 0.884811	valid_1's auc: 0.876277
# [9000]	training's auc: 0.888171	valid_1's auc: 0.879367
# [10000]	training's auc: 0.89082	valid_1's auc: 0.881799
# [11000]	training's auc: 0.893316	valid_1's auc: 0.883747
# [12000]	training's auc: 0.895416	valid_1's auc: 0.885566
# [13000]	training's auc: 0.897157	valid_1's auc: 0.88718
# [14000]	training's auc: 0.898741	valid_1's auc: 0.88846
# [15000]	training's auc: 0.900143	valid_1's auc: 0.889774
# [16000]	training's auc: 0.901396	valid_1's auc: 0.891005
# [17000]	training's auc: 0.902487	valid_1's auc: 0.891828
# [18000]	training's auc: 0.903539	valid_1's auc: 0.892699
# [19000]	training's auc: 0.904459	valid_1's auc: 0.893416
# [20000]	training's auc: 0.905233	valid_1's auc: 0.894055
# [21000]	training's auc: 0.905885	valid_1's auc: 0.894514
# [22000]	training's auc: 0.906564	valid_1's auc: 0.895064
# [23000]	training's auc: 0.907121	valid_1's auc: 0.89541
# [24000]	training's auc: 0.907628	valid_1's auc: 0.895652
# [25000]	training's auc: 0.908115	valid_1's auc: 0.895982
# [26000]	training's auc: 0.908584	valid_1's auc: 0.896273
# [27000]	training's auc: 0.909	valid_1's auc: 0.896532
# [28000]	training's auc: 0.909377	valid_1's auc: 0.896781
# [29000]	training's auc: 0.909724	valid_1's auc: 0.896882
# [30000]	training's auc: 0.910051	valid_1's auc: 0.89705
# [31000]	training's auc: 0.910371	valid_1's auc: 0.89708
# [32000]	training's auc: 0.910663	valid_1's auc: 0.897157
# [33000]	training's auc: 0.910925	valid_1's auc: 0.897254
# [34000]	training's auc: 0.9112	valid_1's auc: 0.89735
# [35000]	training's auc: 0.911432	valid_1's auc: 0.8973
# Early stopping, best iteration is:
# [33909]	training's auc: 0.911177	valid_1's auc: 0.897364
# AUC = 0.8973637036195913
#
#
# Fold 4
# Training until validation scores don't improve for 2000 rounds.
# [1000]	training's auc: 0.789108	valid_1's auc: 0.785988
# [2000]	training's auc: 0.826885	valid_1's auc: 0.823602
# [3000]	training's auc: 0.845963	valid_1's auc: 0.841928
# [4000]	training's auc: 0.858018	valid_1's auc: 0.854275
# [5000]	training's auc: 0.86729	valid_1's auc: 0.864065
# [6000]	training's auc: 0.873892	valid_1's auc: 0.870597
# [7000]	training's auc: 0.879278	valid_1's auc: 0.876082
# [8000]	training's auc: 0.883339	valid_1's auc: 0.880143
# [9000]	training's auc: 0.886571	valid_1's auc: 0.88332
# [10000]	training's auc: 0.889336	valid_1's auc: 0.886115
# [11000]	training's auc: 0.891797	valid_1's auc: 0.888628
# [12000]	training's auc: 0.894043	valid_1's auc: 0.890677
# [13000]	training's auc: 0.895876	valid_1's auc: 0.892311
# [14000]	training's auc: 0.897589	valid_1's auc: 0.894008
# [15000]	training's auc: 0.898894	valid_1's auc: 0.895221
# [16000]	training's auc: 0.900136	valid_1's auc: 0.896337
# [17000]	training's auc: 0.901224	valid_1's auc: 0.897297
# [18000]	training's auc: 0.902144	valid_1's auc: 0.898229
# [19000]	training's auc: 0.903038	valid_1's auc: 0.899077
# [20000]	training's auc: 0.903892	valid_1's auc: 0.899889
# [21000]	training's auc: 0.904532	valid_1's auc: 0.900397
# [22000]	training's auc: 0.905168	valid_1's auc: 0.901067
# [23000]	training's auc: 0.905708	valid_1's auc: 0.901449
# [24000]	training's auc: 0.906258	valid_1's auc: 0.90192
# [25000]	training's auc: 0.906734	valid_1's auc: 0.902277
# [26000]	training's auc: 0.907162	valid_1's auc: 0.902611
# [27000]	training's auc: 0.907576	valid_1's auc: 0.902862
# [28000]	training's auc: 0.90797	valid_1's auc: 0.903089
# [29000]	training's auc: 0.908309	valid_1's auc: 0.903348
# [30000]	training's auc: 0.908625	valid_1's auc: 0.903483
# [31000]	training's auc: 0.908931	valid_1's auc: 0.903618
# [32000]	training's auc: 0.909237	valid_1's auc: 0.903766
# [33000]	training's auc: 0.909469	valid_1's auc: 0.903857
# [34000]	training's auc: 0.909723	valid_1's auc: 0.903876
# [35000]	training's auc: 0.909978	valid_1's auc: 0.904007
# [36000]	training's auc: 0.910196	valid_1's auc: 0.904079
# [37000]	training's auc: 0.910433	valid_1's auc: 0.90406
# [38000]	training's auc: 0.910653	valid_1's auc: 0.90408
# [39000]	training's auc: 0.910844	valid_1's auc: 0.904032
# Early stopping, best iteration is:
# [37760]	training's auc: 0.910597	valid_1's auc: 0.904112
# AUC = 0.9041122829428474
# Overall AUC = 0.8988300749413775

# %%
#結果保存
if (submit_flg ==1 and sampling_flg==0):
    series_oof_preds = pd.Series(data=oof_preds[:,0], name=save_col_name, dtype='float')
    series_oof_preds.to_csv(train_preds_dir,header=True, index=False)

    sample = pd.read_csv(sample_submission_dir)
    sample.target = test_preds[:,0].astype(float)
    sample.ID_code = test_df['ID_code']
    sample.to_csv(test_preds_dir, index=False)
