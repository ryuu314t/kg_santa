# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit

from sklearn.model_selection import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV

warnings.filterwarnings('ignore')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# 基本変数定義

# %%
sampling_flg=0 #サンプリング有無をコントロール
submit_flg=1 #保存するかをコントロール（サンプリングしない時のみ）

SEED=12345
sample_num=10000
fold_num=5

#train関連
train_dir='../../02_feature/114_train_kmeans.csv'
train_feature_dir_1='../../02_feature/113_train_NegativeCount.csv'
train_feature_dir_2='../../02_feature/102_train_kmeans.csv'
train_drop_col=['ID_code', 'target']
train_label='target'

#test関連
test_dir='../../02_feature/114_test_kmeans.csv'
test_feature_dir_1='../../02_feature/113_test_NegativeCount.csv'
test_feature_dir_2='../../02_feature/102_test_kmeans.csv'
test_drop_col=['ID_code']

#結果ファイル関連　nameは自分の名前に変更する
train_preds_dir='../../03_predict_train/oka_222_LightGBM_Mean_NegCount_kmeans_train.csv'
test_preds_dir='../../04_predict_test/oka_222_LightGBM_Mean_NegCount_kmeans_submission.csv'
save_col_name='oof_xgb'

sample_submission_dir='../../01_input/sample_submission.csv'
submission_target_col_name='target'
submission_id_col_name='ID_code'

# %% [markdown]
# 前処理

# %%
#ロード
train_df=pd.read_csv(train_dir)
test_df=pd.read_csv(test_dir)
train_feature_df_1=pd.read_csv(train_feature_dir_1)
test_feature_df_1=pd.read_csv(test_feature_dir_1)
train_feature_df_2=pd.read_csv(train_feature_dir_2)
test_feature_df_2=pd.read_csv(test_feature_dir_2)


train_df=pd.concat([train_df,train_feature_df_1],axis=1)
test_df=pd.concat([test_df,test_feature_df_1],axis=1)
train_df=pd.concat([train_df,train_feature_df_2],axis=1)
test_df=pd.concat([test_df,test_feature_df_2],axis=1)

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7    ...      kmeans_5  kmeans_6  kmeans_7  kmeans_8  kmeans_9  \
# 0  18.6266    ...             0         4         2         0         1
# 1  16.5338    ...             1         1         6         5         5
# 2  14.6155    ...             4         2         1         6         6
# 3  14.9250    ...             4         2         3         7         3
# 4  19.2514    ...             4         2         3         7         3
#
#    kmeans_10  kmeans_11  kmeans_12  kmeans_13  kmeans_14
# 0          9          0          0          6          4
# 1          7          6          5         11          0
# 2          1          1         11          9          6
# 3          5          4          1          3         11
# 4          5          4          1          3          2
#
# [5 rows x 216 columns]

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8    ...      kmeans_5  kmeans_6  kmeans_7  kmeans_8  \
# 0  18.2675  2.1337    ...             1         1         6         5
# 1  18.6316 -4.4131    ...             4         2         1         6
# 2  20.2537  1.5233    ...             1         1         6         5
# 3  20.5660  3.3755    ...             1         1         6         5
# 4  10.6048  2.9890    ...             4         2         1         6
#
#    kmeans_9  kmeans_10  kmeans_11  kmeans_12  kmeans_13  kmeans_14
# 0         5          7          6          5         11          0
# 1         6          1          1         11          9          6
# 2         5          7          6          5         11          0
# 3         7          2          2          4          1         13
# 4         6          1          1         11          9          6
#
# [5 rows x 215 columns]

# %%
#サンプリング
if sampling_flg ==1:
    train_df=train_df.sample(n=sample_num,random_state=SEED)
    test_df=test_df.sample(n=sample_num,random_state=SEED)

# %%
#x,y作成
x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]
x_test=test_df.drop(test_drop_col,axis=1)

# %% [markdown]
# モデル実行

# %%
#model_param
param = {
        'num_leaves': 2,
        'max_bin': 63,
        'min_data_in_leaf': 45,
        'learning_rate': 0.01,
        'min_sum_hessian_in_leaf': 0.000446,
        'bagging_fraction': 0.55, 
        'bagging_freq': 5, 
        'max_depth': 14,
        'save_binary': True,
        'seed': 31452,
        'feature_fraction_seed': 31415,
        'feature_fraction': 0.51,
        'bagging_seed': 31415,
        'drop_seed': 31415,
        'data_random_seed': 31415,
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': 1,
        'metric': 'auc',
        'is_unbalance': True,
        'boost_from_average': False,
    }

# %%
folds = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=SEED)
oof_preds = np.zeros((len(x_train), 1))
test_preds = np.zeros((len(x_test), 1))

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train.values, y_train.values)):
    print("\n")
    print("Fold {}".format(fold_))
    trn_x,trn_y = x_train.iloc[trn_idx], y_train.iloc[trn_idx]
    val_x,val_y = x_train.iloc[val_idx], y_train.iloc[val_idx]
    trn_data = lgb.Dataset(trn_x,trn_y)
    val_data = lgb.Dataset(val_x,val_y)
    
    num_round = 80000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 5000)
    val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
    test_pred = clf.predict(x_test, num_iteration=clf.best_iteration)
    
    print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
    #print("val = {}".format(val_pred)
    oof_preds[val_idx, :] = val_pred.reshape((-1, 1))
    test_preds += test_pred.reshape((-1, 1))
    
test_preds /= fold_num
roc_score = roc_auc_score(y_train, oof_preds.ravel())
print("Overall AUC = {}".format(roc_score))
# Out:
# Fold 0
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.837155	valid_1's auc: 0.831902
# [2000]	training's auc: 0.852914	valid_1's auc: 0.846961
# [3000]	training's auc: 0.861079	valid_1's auc: 0.854475
# [4000]	training's auc: 0.866759	valid_1's auc: 0.859435
# [5000]	training's auc: 0.871195	valid_1's auc: 0.863664
# [6000]	training's auc: 0.874981	valid_1's auc: 0.867064
# [7000]	training's auc: 0.878053	valid_1's auc: 0.8699
# [8000]	training's auc: 0.880636	valid_1's auc: 0.872414
# [9000]	training's auc: 0.882892	valid_1's auc: 0.874494
# [10000]	training's auc: 0.885047	valid_1's auc: 0.876459
# [11000]	training's auc: 0.886901	valid_1's auc: 0.878036
# [12000]	training's auc: 0.888697	valid_1's auc: 0.87958
# [13000]	training's auc: 0.890303	valid_1's auc: 0.880896
# [14000]	training's auc: 0.891725	valid_1's auc: 0.882108
# [15000]	training's auc: 0.893147	valid_1's auc: 0.883348
# [16000]	training's auc: 0.894375	valid_1's auc: 0.884373
# [17000]	training's auc: 0.895548	valid_1's auc: 0.885337
# [18000]	training's auc: 0.896637	valid_1's auc: 0.886322
# [19000]	training's auc: 0.89771	valid_1's auc: 0.887236
# [20000]	training's auc: 0.898686	valid_1's auc: 0.888049
# [21000]	training's auc: 0.899561	valid_1's auc: 0.888747
# [22000]	training's auc: 0.900437	valid_1's auc: 0.889393
# [23000]	training's auc: 0.901303	valid_1's auc: 0.890046
# [24000]	training's auc: 0.901982	valid_1's auc: 0.890545
# [25000]	training's auc: 0.90275	valid_1's auc: 0.89122
# [26000]	training's auc: 0.903444	valid_1's auc: 0.891794
# [27000]	training's auc: 0.904033	valid_1's auc: 0.892203
# [28000]	training's auc: 0.904665	valid_1's auc: 0.892731
# [29000]	training's auc: 0.90522	valid_1's auc: 0.893085
# [30000]	training's auc: 0.905823	valid_1's auc: 0.893487
# [31000]	training's auc: 0.90634	valid_1's auc: 0.893866
# [32000]	training's auc: 0.906784	valid_1's auc: 0.894148
# [33000]	training's auc: 0.907238	valid_1's auc: 0.894463
# [34000]	training's auc: 0.907665	valid_1's auc: 0.894772
# [35000]	training's auc: 0.90808	valid_1's auc: 0.894926
# [36000]	training's auc: 0.908479	valid_1's auc: 0.895145
# [37000]	training's auc: 0.908926	valid_1's auc: 0.89545
# [38000]	training's auc: 0.90932	valid_1's auc: 0.895615
# [39000]	training's auc: 0.909667	valid_1's auc: 0.895778
# [40000]	training's auc: 0.909957	valid_1's auc: 0.895834
# [41000]	training's auc: 0.910317	valid_1's auc: 0.896055
# [42000]	training's auc: 0.910647	valid_1's auc: 0.896187
# [43000]	training's auc: 0.910917	valid_1's auc: 0.896273
# [44000]	training's auc: 0.911255	valid_1's auc: 0.896411
# [45000]	training's auc: 0.911456	valid_1's auc: 0.896452
# [46000]	training's auc: 0.911713	valid_1's auc: 0.896507
# [47000]	training's auc: 0.912004	valid_1's auc: 0.896576
# [48000]	training's auc: 0.912213	valid_1's auc: 0.896665
# [49000]	training's auc: 0.912498	valid_1's auc: 0.896743
# [50000]	training's auc: 0.912688	valid_1's auc: 0.896754
# [51000]	training's auc: 0.912924	valid_1's auc: 0.896717
# [52000]	training's auc: 0.913106	valid_1's auc: 0.896766
# [53000]	training's auc: 0.913322	valid_1's auc: 0.896845
# [54000]	training's auc: 0.913545	valid_1's auc: 0.896951
# [55000]	training's auc: 0.913765	valid_1's auc: 0.896975
# [56000]	training's auc: 0.913964	valid_1's auc: 0.896969
# [57000]	training's auc: 0.914146	valid_1's auc: 0.896988
# [58000]	training's auc: 0.914326	valid_1's auc: 0.896893
# [59000]	training's auc: 0.9145	valid_1's auc: 0.896909
# [60000]	training's auc: 0.914681	valid_1's auc: 0.896903
# [61000]	training's auc: 0.914869	valid_1's auc: 0.896918
# Early stopping, best iteration is:
# [56570]	training's auc: 0.914095	valid_1's auc: 0.897012
# AUC = 0.8970118211919751
#
#
# Fold 1
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.838125	valid_1's auc: 0.836374
# [2000]	training's auc: 0.851828	valid_1's auc: 0.849554
# [3000]	training's auc: 0.859872	valid_1's auc: 0.85716
# [4000]	training's auc: 0.865923	valid_1's auc: 0.862852
# [5000]	training's auc: 0.870457	valid_1's auc: 0.866874
# [6000]	training's auc: 0.87424	valid_1's auc: 0.87025
# [7000]	training's auc: 0.87738	valid_1's auc: 0.873086
# [8000]	training's auc: 0.879957	valid_1's auc: 0.87546
# [9000]	training's auc: 0.882368	valid_1's auc: 0.877546
# [10000]	training's auc: 0.884459	valid_1's auc: 0.879328
# [11000]	training's auc: 0.886384	valid_1's auc: 0.880911
# [12000]	training's auc: 0.888213	valid_1's auc: 0.882441
# [13000]	training's auc: 0.889786	valid_1's auc: 0.883836
# [14000]	training's auc: 0.891194	valid_1's auc: 0.884987
# [15000]	training's auc: 0.892642	valid_1's auc: 0.885936
# [16000]	training's auc: 0.89394	valid_1's auc: 0.887012
# [17000]	training's auc: 0.895234	valid_1's auc: 0.888035
# [18000]	training's auc: 0.896304	valid_1's auc: 0.888877
# [19000]	training's auc: 0.897449	valid_1's auc: 0.889655
# [20000]	training's auc: 0.898487	valid_1's auc: 0.890337
# [21000]	training's auc: 0.899369	valid_1's auc: 0.890918
# [22000]	training's auc: 0.900303	valid_1's auc: 0.891456
# [23000]	training's auc: 0.901087	valid_1's auc: 0.892
# [24000]	training's auc: 0.90187	valid_1's auc: 0.892519
# [25000]	training's auc: 0.902678	valid_1's auc: 0.892957
# [26000]	training's auc: 0.903297	valid_1's auc: 0.893301
# [27000]	training's auc: 0.903985	valid_1's auc: 0.893695
# [28000]	training's auc: 0.904582	valid_1's auc: 0.894047
# [29000]	training's auc: 0.905221	valid_1's auc: 0.894346
# [30000]	training's auc: 0.905753	valid_1's auc: 0.89464
# [31000]	training's auc: 0.906261	valid_1's auc: 0.894853
# [32000]	training's auc: 0.906808	valid_1's auc: 0.895118
# [33000]	training's auc: 0.907274	valid_1's auc: 0.89538
# [34000]	training's auc: 0.907764	valid_1's auc: 0.895575
# [35000]	training's auc: 0.908152	valid_1's auc: 0.895706
# [36000]	training's auc: 0.908533	valid_1's auc: 0.895793
# [37000]	training's auc: 0.908991	valid_1's auc: 0.896045
# [38000]	training's auc: 0.90937	valid_1's auc: 0.896236
# [39000]	training's auc: 0.909727	valid_1's auc: 0.8964
# [40000]	training's auc: 0.910068	valid_1's auc: 0.89643
# [41000]	training's auc: 0.910402	valid_1's auc: 0.89645
# [42000]	training's auc: 0.910703	valid_1's auc: 0.896537
# [43000]	training's auc: 0.911002	valid_1's auc: 0.896649
# [44000]	training's auc: 0.911304	valid_1's auc: 0.89664
# [45000]	training's auc: 0.911571	valid_1's auc: 0.896669
# [46000]	training's auc: 0.911836	valid_1's auc: 0.896699
# [47000]	training's auc: 0.91208	valid_1's auc: 0.896752
# [48000]	training's auc: 0.912325	valid_1's auc: 0.896761
# [49000]	training's auc: 0.91261	valid_1's auc: 0.896731
# [50000]	training's auc: 0.912822	valid_1's auc: 0.896718
# [51000]	training's auc: 0.913003	valid_1's auc: 0.89678
# [52000]	training's auc: 0.913254	valid_1's auc: 0.896802
# [53000]	training's auc: 0.913454	valid_1's auc: 0.896867
# [54000]	training's auc: 0.91369	valid_1's auc: 0.896847
# [55000]	training's auc: 0.913876	valid_1's auc: 0.896819
# [56000]	training's auc: 0.914079	valid_1's auc: 0.896826
# [57000]	training's auc: 0.914272	valid_1's auc: 0.89674
# [58000]	training's auc: 0.914436	valid_1's auc: 0.896751
# Early stopping, best iteration is:
# [53111]	training's auc: 0.913487	valid_1's auc: 0.896894
# AUC = 0.8968942148986593
#
#
# Fold 2
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.836832	valid_1's auc: 0.832328
# [2000]	training's auc: 0.851846	valid_1's auc: 0.846835
# [3000]	training's auc: 0.860506	valid_1's auc: 0.854804
# [4000]	training's auc: 0.866228	valid_1's auc: 0.860161
# [5000]	training's auc: 0.87076	valid_1's auc: 0.864221
# [6000]	training's auc: 0.874494	valid_1's auc: 0.867456
# [7000]	training's auc: 0.877607	valid_1's auc: 0.870228
# [8000]	training's auc: 0.880331	valid_1's auc: 0.872598
# [9000]	training's auc: 0.882849	valid_1's auc: 0.874692
# [10000]	training's auc: 0.88492	valid_1's auc: 0.876458
# [11000]	training's auc: 0.886866	valid_1's auc: 0.878031
# [12000]	training's auc: 0.888602	valid_1's auc: 0.879491
# [13000]	training's auc: 0.890241	valid_1's auc: 0.880875
# [14000]	training's auc: 0.891749	valid_1's auc: 0.882175
# [15000]	training's auc: 0.893151	valid_1's auc: 0.883363
# [16000]	training's auc: 0.894461	valid_1's auc: 0.884481
# [17000]	training's auc: 0.895662	valid_1's auc: 0.885411
# [18000]	training's auc: 0.89678	valid_1's auc: 0.886326
# [19000]	training's auc: 0.897887	valid_1's auc: 0.887186
# [20000]	training's auc: 0.898855	valid_1's auc: 0.887979
# [21000]	training's auc: 0.899774	valid_1's auc: 0.888682
# [22000]	training's auc: 0.900632	valid_1's auc: 0.889355
# [23000]	training's auc: 0.901431	valid_1's auc: 0.890003
# [24000]	training's auc: 0.902293	valid_1's auc: 0.890647
# [25000]	training's auc: 0.902997	valid_1's auc: 0.891129
# [26000]	training's auc: 0.903613	valid_1's auc: 0.891523
# [27000]	training's auc: 0.904352	valid_1's auc: 0.892114
# [28000]	training's auc: 0.904915	valid_1's auc: 0.892499
# [29000]	training's auc: 0.905511	valid_1's auc: 0.892865
# [30000]	training's auc: 0.906017	valid_1's auc: 0.893212
# [31000]	training's auc: 0.906551	valid_1's auc: 0.893553
# [32000]	training's auc: 0.907048	valid_1's auc: 0.893841
# [33000]	training's auc: 0.90752	valid_1's auc: 0.894131
# [34000]	training's auc: 0.907903	valid_1's auc: 0.894303
# [35000]	training's auc: 0.908332	valid_1's auc: 0.894509
# [36000]	training's auc: 0.908744	valid_1's auc: 0.89475
# [37000]	training's auc: 0.909105	valid_1's auc: 0.894998
# [38000]	training's auc: 0.909486	valid_1's auc: 0.895143
# [39000]	training's auc: 0.909828	valid_1's auc: 0.895427
# [40000]	training's auc: 0.910137	valid_1's auc: 0.89554
# [41000]	training's auc: 0.910486	valid_1's auc: 0.895698
# [42000]	training's auc: 0.910766	valid_1's auc: 0.895747
# [43000]	training's auc: 0.911061	valid_1's auc: 0.895775
# [44000]	training's auc: 0.911381	valid_1's auc: 0.895872
# [45000]	training's auc: 0.911693	valid_1's auc: 0.895932
# [46000]	training's auc: 0.911923	valid_1's auc: 0.896015
# [47000]	training's auc: 0.912152	valid_1's auc: 0.896087
# [48000]	training's auc: 0.912405	valid_1's auc: 0.896104
# [49000]	training's auc: 0.912655	valid_1's auc: 0.896155
# [50000]	training's auc: 0.912891	valid_1's auc: 0.89621
# [51000]	training's auc: 0.913091	valid_1's auc: 0.89618
# [52000]	training's auc: 0.91331	valid_1's auc: 0.896253
# [53000]	training's auc: 0.913507	valid_1's auc: 0.896291
# [54000]	training's auc: 0.913696	valid_1's auc: 0.896319
# [55000]	training's auc: 0.913896	valid_1's auc: 0.896319
# [56000]	training's auc: 0.914099	valid_1's auc: 0.89637
# [57000]	training's auc: 0.914264	valid_1's auc: 0.896396
# [58000]	training's auc: 0.914453	valid_1's auc: 0.896363
# [59000]	training's auc: 0.914646	valid_1's auc: 0.89637
# [60000]	training's auc: 0.914816	valid_1's auc: 0.896325
# [61000]	training's auc: 0.914978	valid_1's auc: 0.896295
# [62000]	training's auc: 0.915135	valid_1's auc: 0.896318
# [63000]	training's auc: 0.915296	valid_1's auc: 0.896311
# Early stopping, best iteration is:
# [58794]	training's auc: 0.914625	valid_1's auc: 0.896403
# AUC = 0.8964034883946029
#
#
# Fold 3
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.837027	valid_1's auc: 0.833661
# [2000]	training's auc: 0.851585	valid_1's auc: 0.848251
# [3000]	training's auc: 0.859976	valid_1's auc: 0.856426
# [4000]	training's auc: 0.86599	valid_1's auc: 0.861991
# [5000]	training's auc: 0.870699	valid_1's auc: 0.866022
# [6000]	training's auc: 0.874192	valid_1's auc: 0.869155
# [7000]	training's auc: 0.877361	valid_1's auc: 0.872262
# [8000]	training's auc: 0.880015	valid_1's auc: 0.874642
# [9000]	training's auc: 0.882402	valid_1's auc: 0.876744
# [10000]	training's auc: 0.884462	valid_1's auc: 0.878485
# [11000]	training's auc: 0.886353	valid_1's auc: 0.880099
# [12000]	training's auc: 0.888092	valid_1's auc: 0.881607
# [13000]	training's auc: 0.889692	valid_1's auc: 0.882919
# [14000]	training's auc: 0.89117	valid_1's auc: 0.884117
# [15000]	training's auc: 0.892633	valid_1's auc: 0.885408
# [16000]	training's auc: 0.893927	valid_1's auc: 0.886431
# [17000]	training's auc: 0.895085	valid_1's auc: 0.887342
# [18000]	training's auc: 0.896263	valid_1's auc: 0.888231
# [19000]	training's auc: 0.897251	valid_1's auc: 0.888893
# [20000]	training's auc: 0.898308	valid_1's auc: 0.889634
# [21000]	training's auc: 0.899172	valid_1's auc: 0.890327
# [22000]	training's auc: 0.900067	valid_1's auc: 0.890986
# [23000]	training's auc: 0.900901	valid_1's auc: 0.891517
# [24000]	training's auc: 0.901706	valid_1's auc: 0.892099
# [25000]	training's auc: 0.90254	valid_1's auc: 0.892601
# [26000]	training's auc: 0.903192	valid_1's auc: 0.893025
# [27000]	training's auc: 0.903852	valid_1's auc: 0.893475
# [28000]	training's auc: 0.904499	valid_1's auc: 0.89381
# [29000]	training's auc: 0.905072	valid_1's auc: 0.894139
# [30000]	training's auc: 0.905683	valid_1's auc: 0.89449
# [31000]	training's auc: 0.906198	valid_1's auc: 0.894796
# [32000]	training's auc: 0.906658	valid_1's auc: 0.895044
# [33000]	training's auc: 0.907188	valid_1's auc: 0.895352
# [34000]	training's auc: 0.907563	valid_1's auc: 0.895469
# [35000]	training's auc: 0.908023	valid_1's auc: 0.895698
# [36000]	training's auc: 0.908458	valid_1's auc: 0.895884
# [37000]	training's auc: 0.908812	valid_1's auc: 0.89599
# [38000]	training's auc: 0.909229	valid_1's auc: 0.896182
# [39000]	training's auc: 0.909573	valid_1's auc: 0.896247
# [40000]	training's auc: 0.909926	valid_1's auc: 0.896334
# [41000]	training's auc: 0.910261	valid_1's auc: 0.896441
# [42000]	training's auc: 0.91057	valid_1's auc: 0.896466
# [43000]	training's auc: 0.910905	valid_1's auc: 0.896587
# [44000]	training's auc: 0.911151	valid_1's auc: 0.896624
# [45000]	training's auc: 0.911462	valid_1's auc: 0.896711
# [46000]	training's auc: 0.911707	valid_1's auc: 0.89673
# [47000]	training's auc: 0.911965	valid_1's auc: 0.896727
# [48000]	training's auc: 0.912202	valid_1's auc: 0.896789
# [49000]	training's auc: 0.912466	valid_1's auc: 0.896841
# [50000]	training's auc: 0.912713	valid_1's auc: 0.896858
# [51000]	training's auc: 0.912961	valid_1's auc: 0.896843
# [52000]	training's auc: 0.913173	valid_1's auc: 0.896875
# [53000]	training's auc: 0.913384	valid_1's auc: 0.896874
# [54000]	training's auc: 0.913602	valid_1's auc: 0.896899
# [55000]	training's auc: 0.913806	valid_1's auc: 0.896846
# [56000]	training's auc: 0.913997	valid_1's auc: 0.896811
# [57000]	training's auc: 0.914182	valid_1's auc: 0.896769
# [58000]	training's auc: 0.914371	valid_1's auc: 0.896741
# Early stopping, best iteration is:
# [53932]	training's auc: 0.913591	valid_1's auc: 0.896915
# AUC = 0.8969151602152146
#
#
# Fold 4
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.835939	valid_1's auc: 0.837511
# [2000]	training's auc: 0.85021	valid_1's auc: 0.852287
# [3000]	training's auc: 0.858432	valid_1's auc: 0.860562
# [4000]	training's auc: 0.864425	valid_1's auc: 0.866433
# [5000]	training's auc: 0.868978	valid_1's auc: 0.870657
# [6000]	training's auc: 0.8728	valid_1's auc: 0.874342
# [7000]	training's auc: 0.875889	valid_1's auc: 0.877402
# [8000]	training's auc: 0.878442	valid_1's auc: 0.879932
# [9000]	training's auc: 0.880878	valid_1's auc: 0.881848
# [10000]	training's auc: 0.883002	valid_1's auc: 0.883803
# [11000]	training's auc: 0.885046	valid_1's auc: 0.885663
# [12000]	training's auc: 0.886824	valid_1's auc: 0.887245
# [13000]	training's auc: 0.88843	valid_1's auc: 0.888629
# [14000]	training's auc: 0.889868	valid_1's auc: 0.889889
# [15000]	training's auc: 0.891273	valid_1's auc: 0.891161
# [16000]	training's auc: 0.892605	valid_1's auc: 0.892096
# [17000]	training's auc: 0.893829	valid_1's auc: 0.893078
# [18000]	training's auc: 0.894913	valid_1's auc: 0.894064
# [19000]	training's auc: 0.895991	valid_1's auc: 0.894918
# [20000]	training's auc: 0.896986	valid_1's auc: 0.895742
# [21000]	training's auc: 0.897957	valid_1's auc: 0.896421
# [22000]	training's auc: 0.898748	valid_1's auc: 0.896971
# [23000]	training's auc: 0.89961	valid_1's auc: 0.897614
# [24000]	training's auc: 0.90038	valid_1's auc: 0.898217
# [25000]	training's auc: 0.90113	valid_1's auc: 0.898754
# [26000]	training's auc: 0.901866	valid_1's auc: 0.899184
# [27000]	training's auc: 0.902503	valid_1's auc: 0.899599
# [28000]	training's auc: 0.903103	valid_1's auc: 0.900034
# [29000]	training's auc: 0.903721	valid_1's auc: 0.90043
# [30000]	training's auc: 0.904307	valid_1's auc: 0.90073
# [31000]	training's auc: 0.904765	valid_1's auc: 0.901041
# [32000]	training's auc: 0.90527	valid_1's auc: 0.901325
# [33000]	training's auc: 0.905781	valid_1's auc: 0.901581
# [34000]	training's auc: 0.906133	valid_1's auc: 0.901705
# [35000]	training's auc: 0.906668	valid_1's auc: 0.901954
# [36000]	training's auc: 0.907057	valid_1's auc: 0.902144
# [37000]	training's auc: 0.907437	valid_1's auc: 0.902255
# [38000]	training's auc: 0.90785	valid_1's auc: 0.90252
# [39000]	training's auc: 0.908192	valid_1's auc: 0.902627
# [40000]	training's auc: 0.908496	valid_1's auc: 0.902716
# [41000]	training's auc: 0.908879	valid_1's auc: 0.902809
# [42000]	training's auc: 0.909145	valid_1's auc: 0.902828
# [43000]	training's auc: 0.909438	valid_1's auc: 0.902886
# [44000]	training's auc: 0.909725	valid_1's auc: 0.902958
# [45000]	training's auc: 0.910033	valid_1's auc: 0.903059
# [46000]	training's auc: 0.910302	valid_1's auc: 0.903152
# [47000]	training's auc: 0.910561	valid_1's auc: 0.903224
# [48000]	training's auc: 0.910815	valid_1's auc: 0.903215
# [49000]	training's auc: 0.911049	valid_1's auc: 0.903254
# [50000]	training's auc: 0.911263	valid_1's auc: 0.903304
# [51000]	training's auc: 0.911496	valid_1's auc: 0.903323
# [52000]	training's auc: 0.911701	valid_1's auc: 0.903305
# [53000]	training's auc: 0.9119	valid_1's auc: 0.90323
# [54000]	training's auc: 0.912116	valid_1's auc: 0.903224
# [55000]	training's auc: 0.912338	valid_1's auc: 0.903235
# Early stopping, best iteration is:
# [50502]	training's auc: 0.911376	valid_1's auc: 0.903349
# AUC = 0.9033494182234166
# Overall AUC = 0.8980804078801878

# %%
#結果保存
if (submit_flg ==1 and sampling_flg==0):
    series_oof_preds = pd.Series(data=oof_preds[:,0], name=save_col_name, dtype='float')
    series_oof_preds.to_csv(train_preds_dir,header=True, index=False)

    sample = pd.read_csv(sample_submission_dir)
    sample.target = test_preds[:,0].astype(float)
    sample.ID_code = test_df['ID_code']
    sample.to_csv(test_preds_dir, index=False)
