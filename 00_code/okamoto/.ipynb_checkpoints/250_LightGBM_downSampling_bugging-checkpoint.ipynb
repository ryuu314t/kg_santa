# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

warnings.filterwarnings('ignore')

# %% [markdown]
# 基本変数定義

# %%
sampling_flg=0 #サンプリング有無をコントロール
submit_flg=1 #保存するかをコントロール（サンプリングしない時のみ）

SEED=12345
sample_num=10000
fold_num=5

#train関連
train_dir='../../01_input/train.csv'
train_FN_dir='../../03_predict_train/FalseNegative_train.csv'
train_drop_col=['ID_code', 'target']
train_label='target'

#test関連
test_dir='../../01_input/test.csv'
test_drop_col=['ID_code']

#結果ファイル関連　nameは自分の名前に変更する
train_preds_dir='../../03_predict_train/oka_250_LightGBM_train.csv'
test_preds_dir='../../04_predict_test/oka_250_LightGBM_submission.csv'
save_col_name='oof_xgb'

sample_submission_dir='../../01_input/sample_submission.csv'
submission_target_col_name='target'
submission_id_col_name='ID_code'

# %% [markdown]
# 前処理

# %%
#ロード
train_df=pd.read_csv(train_dir)
test_df=pd.read_csv(test_dir)
train_FN_df=pd.read_csv(train_FN_dir)

# %%
#サンプリング
if sampling_flg ==1:
    train_df=train_df.sample(n=sample_num,random_state=SEED)
    test_df=test_df.sample(n=sample_num,random_state=SEED)

# %%
#x,y作成
x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]
x_train_base=train_df.drop(train_drop_col,axis=1)
y_train_base=train_df[train_label]
x_test=test_df.drop(test_drop_col,axis=1)
x_train_col=x_train.columns

# %% [markdown]
# モデル実行

# %%
def lgbm(train_x,train_y,test_x,test_y):
    #model_param
    param = {
        "objective" : "binary", 
        "boost":"gbdt",
        "metric":"auc",
        "boost_from_average":"false",
        "num_threads":28,
        "learning_rate" : 0.01,
        "num_leaves" : 13,
        "max_depth":-1,
        "tree_learner" : "serial",
        "feature_fraction" : 0.05,
        "bagging_freq" : 5,
        "bagging_fraction" : 0.4,
        "min_data_in_leaf" : 80,
        "min_sum_hessian_in_leaf" : 10.0,
        "verbosity" : 1,
        'seed': i,
        }

    trn_data = lgb.Dataset(train_x,train_y)
    val_data = lgb.Dataset(test_x,test_y)
    
    num_round = 1000000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 3000)
    
    val_pred = clf.predict(test_x, num_iteration=clf.best_iteration)
    auc_score=roc_auc_score(test_y, val_pred)
    print("")
    print("AUC = {}".format(auc_score))
    print(confusion_matrix(test_y, pd.DataFrame(np.round(val_pred))))
    
    return val_pred,clf

# %%
y_test = np.zeros((len(x_test), 1))
y_train_preds = np.zeros((len(x_train), 1))
y_test_preds = np.zeros((len(x_test), 1))
for i in range(0,10):
    print(i)
    train_df_sample=train_df.sample(n=len(train_df[train_df['target']==1]),random_state=i)
    x_train_sample=train_df_sample.drop(train_drop_col,axis=1)
    y_train_sample=train_df_sample[train_label]

    y_val_pred,model=lgbm(x_train_sample,y_train_sample,x_train,y_train)
    
    y_train_pred=model.predict(x_train)
    y_test_pred=model.predict(x_test)
    
    y_train_preds+=y_train_pred.reshape((-1, 1))
    y_test_preds+=y_test_pred.reshape((-1, 1))
    
    y_train_preds_tmp=y_train_preds/(i+1)
    y_test_preds_tmp=y_test_preds/(i+1)
    print("means AUC = {}".format(roc_auc_score(y_train, y_train_preds_tmp)))
    print(confusion_matrix(y_train, pd.DataFrame(np.round(y_train_preds_tmp))))

print("Over All AUC = {}".format(roc_auc_score(y_train, y_train_preds_tmp)))
# Out:
# 0
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.965772	valid_1's auc: 0.890138
# [2000]	training's auc: 0.980589	valid_1's auc: 0.896433
# [3000]	training's auc: 0.989815	valid_1's auc: 0.898692
# [4000]	training's auc: 0.995115	valid_1's auc: 0.898953
# [5000]	training's auc: 0.997996	valid_1's auc: 0.898826
# [6000]	training's auc: 0.999379	valid_1's auc: 0.898326
# [7000]	training's auc: 0.999859	valid_1's auc: 0.898077
# Early stopping, best iteration is:
# [4150]	training's auc: 0.995645	valid_1's auc: 0.899123
#
# AUC = 0.8991225922021239
# [[179303    599]
#  [ 15468   4630]]
# means AUC = 0.8991225922021239
# [[179303    599]
#  [ 15468   4630]]
# 1
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.965528	valid_1's auc: 0.889408
# [2000]	training's auc: 0.980558	valid_1's auc: 0.895327
# [3000]	training's auc: 0.989777	valid_1's auc: 0.897445
# [4000]	training's auc: 0.995029	valid_1's auc: 0.897899
# [5000]	training's auc: 0.998001	valid_1's auc: 0.89771
# [6000]	training's auc: 0.999277	valid_1's auc: 0.897323
# [7000]	training's auc: 0.999784	valid_1's auc: 0.896827
# Early stopping, best iteration is:
# [4046]	training's auc: 0.995253	valid_1's auc: 0.897922
#
# AUC = 0.8979221550702434
# [[179273    629]
#  [ 15454   4644]]
# means AUC = 0.9105391466661775
# [[179433    469]
#  [ 15798   4300]]
# 2
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.965157	valid_1's auc: 0.889586
# [2000]	training's auc: 0.980252	valid_1's auc: 0.895505
# [3000]	training's auc: 0.989425	valid_1's auc: 0.897647
# [4000]	training's auc: 0.994641	valid_1's auc: 0.898247
# [5000]	training's auc: 0.997604	valid_1's auc: 0.89824
# [6000]	training's auc: 0.999083	valid_1's auc: 0.897945
# [7000]	training's auc: 0.99972	valid_1's auc: 0.897599
# Early stopping, best iteration is:
# [4590]	training's auc: 0.996633	valid_1's auc: 0.898492
#
# AUC = 0.8984924584370217
# [[179253    649]
#  [ 15114   4984]]
# means AUC = 0.916139632546307
# [[179471    431]
#  [ 15794   4304]]
# 3
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.965759	valid_1's auc: 0.889748
# [2000]	training's auc: 0.981005	valid_1's auc: 0.895611
# [3000]	training's auc: 0.990007	valid_1's auc: 0.89719
# [4000]	training's auc: 0.995379	valid_1's auc: 0.897462
# [5000]	training's auc: 0.998031	valid_1's auc: 0.897422
# [6000]	training's auc: 0.999335	valid_1's auc: 0.896927
# [7000]	training's auc: 0.999833	valid_1's auc: 0.896439
# Early stopping, best iteration is:
# [4414]	training's auc: 0.996694	valid_1's auc: 0.897651
#
# AUC = 0.8976511375568427
# [[179164    738]
#  [ 15116   4982]]
# means AUC = 0.9192908766454939
# [[179486    416]
#  [ 15813   4285]]
# 4
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.965585	valid_1's auc: 0.889038
# [2000]	training's auc: 0.980384	valid_1's auc: 0.894919
# [3000]	training's auc: 0.989596	valid_1's auc: 0.896835
# [4000]	training's auc: 0.994878	valid_1's auc: 0.897578
# [5000]	training's auc: 0.997824	valid_1's auc: 0.897496
# [6000]	training's auc: 0.999207	valid_1's auc: 0.897233
# [7000]	training's auc: 0.999746	valid_1's auc: 0.896816
# Early stopping, best iteration is:
# [4188]	training's auc: 0.995563	valid_1's auc: 0.89769
#
# AUC = 0.8976898708993939
# [[179259    643]
#  [ 15436   4662]]
# means AUC = 0.9219652935422049
# [[179493    409]
#  [ 15880   4218]]
# 5
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.967511	valid_1's auc: 0.889521
# [2000]	training's auc: 0.982222	valid_1's auc: 0.895556
# [3000]	training's auc: 0.990855	valid_1's auc: 0.897968
# [4000]	training's auc: 0.995739	valid_1's auc: 0.89906
# [5000]	training's auc: 0.998423	valid_1's auc: 0.899386
# [6000]	training's auc: 0.999537	valid_1's auc: 0.898922
# [7000]	training's auc: 0.999908	valid_1's auc: 0.898488
# Early stopping, best iteration is:
# [4939]	training's auc: 0.998319	valid_1's auc: 0.899449
#
# AUC = 0.8994493896893361
# [[179158    744]
#  [ 14859   5239]]
# means AUC = 0.9239078978812978
# [[179482    420]
#  [ 15841   4257]]
# 6
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.965476	valid_1's auc: 0.88832
# [2000]	training's auc: 0.979237	valid_1's auc: 0.893772
# [3000]	training's auc: 0.988557	valid_1's auc: 0.89647
# [4000]	training's auc: 0.99432	valid_1's auc: 0.897278
# [5000]	training's auc: 0.997501	valid_1's auc: 0.897655
# [6000]	training's auc: 0.999081	valid_1's auc: 0.897487
# [7000]	training's auc: 0.999712	valid_1's auc: 0.897096
# [8000]	training's auc: 0.999931	valid_1's auc: 0.896663
# Early stopping, best iteration is:
# [5085]	training's auc: 0.997689	valid_1's auc: 0.897726
#
# AUC = 0.8977264779419346
# [[178952    950]
#  [ 14438   5660]]
# means AUC = 0.925526446963226
# [[179472    430]
#  [ 15757   4341]]
# 7
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.963615	valid_1's auc: 0.888161
# [2000]	training's auc: 0.978737	valid_1's auc: 0.895593
# [3000]	training's auc: 0.988149	valid_1's auc: 0.897702
# [4000]	training's auc: 0.993988	valid_1's auc: 0.898294
# [5000]	training's auc: 0.997174	valid_1's auc: 0.898373
# [6000]	training's auc: 0.998855	valid_1's auc: 0.897966
# [7000]	training's auc: 0.999609	valid_1's auc: 0.897633
# Early stopping, best iteration is:
# [4291]	training's auc: 0.99511	valid_1's auc: 0.89848
#
# AUC = 0.8984802772935058
# [[179269    633]
#  [ 15393   4705]]
# means AUC = 0.9265144692685644
# [[179487    415]
#  [ 15805   4293]]
# 8
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.963285	valid_1's auc: 0.889239
# [2000]	training's auc: 0.978749	valid_1's auc: 0.895695
# [3000]	training's auc: 0.988279	valid_1's auc: 0.898325
# [4000]	training's auc: 0.994042	valid_1's auc: 0.899684
# [5000]	training's auc: 0.997215	valid_1's auc: 0.899966
# [6000]	training's auc: 0.998865	valid_1's auc: 0.899673
# [7000]	training's auc: 0.999618	valid_1's auc: 0.899306
# Early stopping, best iteration is:
# [4786]	training's auc: 0.996684	valid_1's auc: 0.900028
#
# AUC = 0.9000281293892586
# [[179089    813]
#  [ 14818   5280]]
# means AUC = 0.9275307187043718
# [[179489    413]
#  [ 15773   4325]]
# 9
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.963289	valid_1's auc: 0.887746
# [2000]	training's auc: 0.978933	valid_1's auc: 0.894845
# [3000]	training's auc: 0.988181	valid_1's auc: 0.897343
# [4000]	training's auc: 0.99406	valid_1's auc: 0.898494
# [5000]	training's auc: 0.997329	valid_1's auc: 0.898709
# [6000]	training's auc: 0.998985	valid_1's auc: 0.898482
# [7000]	training's auc: 0.999698	valid_1's auc: 0.897971
# Early stopping, best iteration is:
# [4614]	training's auc: 0.996333	valid_1's auc: 0.898809
#
# AUC = 0.8988086341042686
# [[179105    797]
#  [ 14929   5169]]
# means AUC = 0.9281863163502806
# [[179474    428]
#  [ 15756   4342]]
# Over All AUC = 0.9281863163502806

# %%
y_train_preds_save=y_train_preds_tmp.reshape((-1, 1))
y_test_preds_save=y_test_preds_tmp.reshape((-1, 1))

# %%
# Out:
# (200000, 1)

# %%
#結果保存
if (submit_flg ==1 and sampling_flg==0):

    sample = pd.read_csv(sample_submission_dir)
    sample.target = y_test_preds_save.astype(float)
    sample.ID_code = test_df['ID_code']
    sample.to_csv(test_preds_dir, index=False)
