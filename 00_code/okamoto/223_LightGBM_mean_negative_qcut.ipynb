# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit

from sklearn.model_selection import GridSearchCV
from sklearn.grid_search import RandomizedSearchCV

warnings.filterwarnings('ignore')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# 基本変数定義

# %%
sampling_flg=0 #サンプリング有無をコントロール
submit_flg=1 #保存するかをコントロール（サンプリングしない時のみ）

SEED=12345
sample_num=10000
fold_num=5

#train関連
train_dir='../../02_feature/114_train_kmeans.csv'
train_feature_dir_1='../../02_feature/113_train_NegativeCount.csv'
train_feature_dir_2='../../02_feature/116_train_quantile.csv'
train_drop_col=['ID_code', 'target']
train_label='target'

#test関連
test_dir='../../02_feature/114_test_kmeans.csv'
test_feature_dir_1='../../02_feature/113_test_NegativeCount.csv'
test_feature_dir_2='../../02_feature/116_test_quantile.csv'
test_drop_col=['ID_code']

#結果ファイル関連　nameは自分の名前に変更する
train_preds_dir='../../03_predict_train/oka_222_LightGBM_Mean_NegCount_kmeans_train.csv'
test_preds_dir='../../04_predict_test/oka_222_LightGBM_Mean_NegCount_kmeans_submission.csv'
save_col_name='oof_xgb'

sample_submission_dir='../../01_input/sample_submission.csv'
submission_target_col_name='target'
submission_id_col_name='ID_code'

# %% [markdown]
# 前処理

# %%
#ロード
train_df=pd.read_csv(train_dir)
test_df=pd.read_csv(test_dir)
train_feature_df_1=pd.read_csv(train_feature_dir_1)
test_feature_df_1=pd.read_csv(test_feature_dir_1)
train_feature_df_2=pd.read_csv(train_feature_dir_2)
test_feature_df_2=pd.read_csv(test_feature_dir_2)


train_df=pd.concat([train_df,train_feature_df_1],axis=1)
test_df=pd.concat([test_df,test_feature_df_1],axis=1)
train_df=pd.concat([train_df,train_feature_df_2],axis=1)
test_df=pd.concat([test_df,test_feature_df_2],axis=1)

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7      ...       var_190_qcut  var_191_qcut  var_192_qcut  \
# 0  18.6266      ...                  6             1             7
# 1  16.5338      ...                  8             5             6
# 2  14.6155      ...                  4             7             4
# 3  14.9250      ...                  6             2             2
# 4  19.2514      ...                  1             7             0
#
#    var_193_qcut  var_194_qcut  var_195_qcut  var_196_qcut  var_197_qcut  \
# 0             3             5             0             8             3
# 1             9             2             9             8             4
# 2             3             8             9             0             2
# 3             3             9             2             2             9
# 4             9             0             1             5             7
#
#    var_198_qcut  var_199_qcut
# 0             1             5
# 1             7             6
# 2             3             6
# 3             7             3
# 4             7             3
#
# [5 rows x 403 columns]

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8      ...       var_190_qcut  var_191_qcut  var_192_qcut  \
# 0  18.2675  2.1337      ...                  1             9             0
# 1  18.6316 -4.4131      ...                  9             6             2
# 2  20.2537  1.5233      ...                  2             8             5
# 3  20.5660  3.3755      ...                  9             6             4
# 4  10.6048  2.9890      ...                  5             7             3
#
#    var_193_qcut  var_194_qcut  var_195_qcut  var_196_qcut  var_197_qcut  \
# 0             4             0             9             6             9
# 1             9             2             6             2             8
# 2             3             0             9             0             0
# 3             5             2             9             5             6
# 4             4             6             4             0             0
#
#    var_198_qcut  var_199_qcut
# 0             4             3
# 1             8             0
# 2             9             0
# 3             1             4
# 4             2             3
#
# [5 rows x 402 columns]

# %%
#サンプリング
if sampling_flg ==1:
    train_df=train_df.sample(n=sample_num,random_state=SEED)
    test_df=test_df.sample(n=sample_num,random_state=SEED)

# %%
#x,y作成
x_train=train_df.drop(train_drop_col,axis=1)
y_train=train_df[train_label]
x_test=test_df.drop(test_drop_col,axis=1)

# %% [markdown]
# モデル実行

# %%
#model_param
param = {
        'num_leaves': 2,
        'max_bin': 63,
        'min_data_in_leaf': 45,
        'learning_rate': 0.01,
        'min_sum_hessian_in_leaf': 0.000446,
        'bagging_fraction': 0.55, 
        'bagging_freq': 5, 
        'max_depth': 14,
        'save_binary': True,
        'seed': 31452,
        'feature_fraction_seed': 31415,
        'feature_fraction': 0.51,
        'bagging_seed': 31415,
        'drop_seed': 31415,
        'data_random_seed': 31415,
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': 1,
        'metric': 'auc',
        'is_unbalance': True,
        'boost_from_average': False,
    }

# %%
folds = StratifiedKFold(n_splits=fold_num, shuffle=True, random_state=SEED)
oof_preds = np.zeros((len(x_train), 1))
test_preds = np.zeros((len(x_test), 1))

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train.values, y_train.values)):
    print("\n")
    print("Fold {}".format(fold_))
    trn_x,trn_y = x_train.iloc[trn_idx], y_train.iloc[trn_idx]
    val_x,val_y = x_train.iloc[val_idx], y_train.iloc[val_idx]
    trn_data = lgb.Dataset(trn_x,trn_y)
    val_data = lgb.Dataset(val_x,val_y)
    
    num_round = 80000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 5000)
    val_pred = clf.predict(val_x, num_iteration=clf.best_iteration)
    test_pred = clf.predict(x_test, num_iteration=clf.best_iteration)
    
    print("AUC = {}".format(roc_auc_score(val_y, val_pred)))
    #print("val = {}".format(val_pred)
    oof_preds[val_idx, :] = val_pred.reshape((-1, 1))
    test_preds += test_pred.reshape((-1, 1))
    
test_preds /= fold_num
roc_score = roc_auc_score(y_train, oof_preds.ravel())
print("Overall AUC = {}".format(roc_score))
# Out:
# Fold 0
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.790409	valid_1's auc: 0.785249
# [2000]	training's auc: 0.827763	valid_1's auc: 0.823758
# [3000]	training's auc: 0.847643	valid_1's auc: 0.843321
# [4000]	training's auc: 0.859438	valid_1's auc: 0.854835
# [5000]	training's auc: 0.868903	valid_1's auc: 0.863453
# [6000]	training's auc: 0.875573	valid_1's auc: 0.869486
# [7000]	training's auc: 0.880979	valid_1's auc: 0.874199
# [8000]	training's auc: 0.884883	valid_1's auc: 0.877578
# [9000]	training's auc: 0.888374	valid_1's auc: 0.880397
# [10000]	training's auc: 0.891482	valid_1's auc: 0.882942
# [11000]	training's auc: 0.8936	valid_1's auc: 0.884883
# [12000]	training's auc: 0.895651	valid_1's auc: 0.886533
# [13000]	training's auc: 0.897504	valid_1's auc: 0.888085
# [14000]	training's auc: 0.898944	valid_1's auc: 0.889088
# [15000]	training's auc: 0.90031	valid_1's auc: 0.890224
# [16000]	training's auc: 0.901539	valid_1's auc: 0.891375
# [17000]	training's auc: 0.90263	valid_1's auc: 0.892233
# [18000]	training's auc: 0.903595	valid_1's auc: 0.893075
# [19000]	training's auc: 0.90443	valid_1's auc: 0.893763
# [20000]	training's auc: 0.905177	valid_1's auc: 0.894313
# [21000]	training's auc: 0.905914	valid_1's auc: 0.894868
# [40000]	training's auc: 0.912587	valid_1's auc: 0.896475
# [41000]	training's auc: 0.912781	valid_1's auc: 0.896518
# [42000]	training's auc: 0.912969	valid_1's auc: 0.896565
# [43000]	training's auc: 0.913154	valid_1's auc: 0.89659
# [44000]	training's auc: 0.913331	valid_1's auc: 0.896586
# [45000]	training's auc: 0.913509	valid_1's auc: 0.89656
# [46000]	training's auc: 0.913703	valid_1's auc: 0.896524
# [47000]	training's auc: 0.913878	valid_1's auc: 0.896513
# [48000]	training's auc: 0.914046	valid_1's auc: 0.896479
# Early stopping, best iteration is:
# [43880]	training's auc: 0.913315	valid_1's auc: 0.896618
# AUC = 0.8966175514865915
#
#
# Fold 3
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.789981	valid_1's auc: 0.786614
# [2000]	training's auc: 0.82763	valid_1's auc: 0.822998
# [3000]	training's auc: 0.847775	valid_1's auc: 0.842125
# [4000]	training's auc: 0.860258	valid_1's auc: 0.853516
# [5000]	training's auc: 0.868825	valid_1's auc: 0.861244
# [6000]	training's auc: 0.875365	valid_1's auc: 0.867291
# [7000]	training's auc: 0.880657	valid_1's auc: 0.872157
# [8000]	training's auc: 0.884852	valid_1's auc: 0.876154
# [9000]	training's auc: 0.888111	valid_1's auc: 0.879201
# [10000]	training's auc: 0.890882	valid_1's auc: 0.881618
# [11000]	training's auc: 0.893293	valid_1's auc: 0.883563
# [12000]	training's auc: 0.895373	valid_1's auc: 0.885459
# [13000]	training's auc: 0.897234	valid_1's auc: 0.887136
# [14000]	training's auc: 0.89873	valid_1's auc: 0.888341
# [15000]	training's auc: 0.900076	valid_1's auc: 0.889585
# [16000]	training's auc: 0.901302	valid_1's auc: 0.890873
# [17000]	training's auc: 0.902434	valid_1's auc: 0.891747
# [18000]	training's auc: 0.903469	valid_1's auc: 0.892621
# [19000]	training's auc: 0.904369	valid_1's auc: 0.893305
# [20000]	training's auc: 0.905175	valid_1's auc: 0.89396
# [21000]	training's auc: 0.905854	valid_1's auc: 0.894422
# [22000]	training's auc: 0.906476	valid_1's auc: 0.894938
# [23000]	training's auc: 0.907047	valid_1's auc: 0.895275
# [24000]	training's auc: 0.907571	valid_1's auc: 0.895549
# [25000]	training's auc: 0.908032	valid_1's auc: 0.895954
# [26000]	training's auc: 0.908493	valid_1's auc: 0.896196
# [27000]	training's auc: 0.908877	valid_1's auc: 0.896434
# [28000]	training's auc: 0.909253	valid_1's auc: 0.896672
# [29000]	training's auc: 0.90963	valid_1's auc: 0.896841
# [30000]	training's auc: 0.909964	valid_1's auc: 0.896959
# [31000]	training's auc: 0.91027	valid_1's auc: 0.897008
# [32000]	training's auc: 0.910537	valid_1's auc: 0.897064
# [33000]	training's auc: 0.910796	valid_1's auc: 0.897194
# [34000]	training's auc: 0.911056	valid_1's auc: 0.897272
# [35000]	training's auc: 0.911314	valid_1's auc: 0.897246
# [36000]	training's auc: 0.911549	valid_1's auc: 0.897283
# [37000]	training's auc: 0.911771	valid_1's auc: 0.897326
# [38000]	training's auc: 0.912003	valid_1's auc: 0.897332
# [39000]	training's auc: 0.912212	valid_1's auc: 0.89735
# [40000]	training's auc: 0.912393	valid_1's auc: 0.897394
# [41000]	training's auc: 0.912606	valid_1's auc: 0.897441
# [42000]	training's auc: 0.912802	valid_1's auc: 0.897419
# [43000]	training's auc: 0.912996	valid_1's auc: 0.897354
# [44000]	training's auc: 0.913189	valid_1's auc: 0.897276
# [45000]	training's auc: 0.913372	valid_1's auc: 0.897214
# Early stopping, best iteration is:
# [40905]	training's auc: 0.912589	valid_1's auc: 0.897457
# AUC = 0.8974565574499447
#
#
# Fold 4
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.790315	valid_1's auc: 0.787025
# [2000]	training's auc: 0.827213	valid_1's auc: 0.823829
# [3000]	training's auc: 0.845741	valid_1's auc: 0.84183
# [4000]	training's auc: 0.85812	valid_1's auc: 0.854146
# [5000]	training's auc: 0.867101	valid_1's auc: 0.86372
# [6000]	training's auc: 0.873904	valid_1's auc: 0.870656
# [7000]	training's auc: 0.879329	valid_1's auc: 0.876214
# [8000]	training's auc: 0.883517	valid_1's auc: 0.880422
# [9000]	training's auc: 0.886601	valid_1's auc: 0.883429
# [10000]	training's auc: 0.889287	valid_1's auc: 0.886225
# [11000]	training's auc: 0.891849	valid_1's auc: 0.888875
# [12000]	training's auc: 0.894019	valid_1's auc: 0.890895
# [13000]	training's auc: 0.895787	valid_1's auc: 0.892432
# [14000]	training's auc: 0.897505	valid_1's auc: 0.894087
# [15000]	training's auc: 0.898883	valid_1's auc: 0.895303
# [16000]	training's auc: 0.900089	valid_1's auc: 0.896448
# [17000]	training's auc: 0.901221	valid_1's auc: 0.897463
# [18000]	training's auc: 0.902128	valid_1's auc: 0.898383
# [19000]	training's auc: 0.903035	valid_1's auc: 0.899238
# [20000]	training's auc: 0.903876	valid_1's auc: 0.900049
# [21000]	training's auc: 0.904516	valid_1's auc: 0.900492
# [22000]	training's auc: 0.905148	valid_1's auc: 0.901162
# [23000]	training's auc: 0.905674	valid_1's auc: 0.901546
# [24000]	training's auc: 0.906207	valid_1's auc: 0.901983
# [25000]	training's auc: 0.906664	valid_1's auc: 0.902377
# [26000]	training's auc: 0.907079	valid_1's auc: 0.90259
# [27000]	training's auc: 0.907513	valid_1's auc: 0.902912
# [28000]	training's auc: 0.907907	valid_1's auc: 0.903128
# [29000]	training's auc: 0.908242	valid_1's auc: 0.903307
# [30000]	training's auc: 0.908549	valid_1's auc: 0.903458
# [31000]	training's auc: 0.908849	valid_1's auc: 0.903558
# [32000]	training's auc: 0.909168	valid_1's auc: 0.9037
# [33000]	training's auc: 0.909428	valid_1's auc: 0.903851
# [34000]	training's auc: 0.909677	valid_1's auc: 0.903881
# [35000]	training's auc: 0.909943	valid_1's auc: 0.903983
# [36000]	training's auc: 0.910166	valid_1's auc: 0.904084
# [37000]	training's auc: 0.910393	valid_1's auc: 0.9041
# [38000]	training's auc: 0.910615	valid_1's auc: 0.90409
# [39000]	training's auc: 0.910802	valid_1's auc: 0.904023
# [40000]	training's auc: 0.911017	valid_1's auc: 0.904002
# [41000]	training's auc: 0.911226	valid_1's auc: 0.903979
# Early stopping, best iteration is:
# [36461]	training's auc: 0.910271	valid_1's auc: 0.904128
# AUC = 0.9041278565502026
# Overall AUC = 0.898745653529421

# %%
#結果保存
if (submit_flg ==1 and sampling_flg==0):
    series_oof_preds = pd.Series(data=oof_preds[:,0], name=save_col_name, dtype='float')
    series_oof_preds.to_csv(train_preds_dir,header=True, index=False)

    sample = pd.read_csv(sample_submission_dir)
    sample.target = test_preds[:,0].astype(float)
    sample.ID_code = test_df['ID_code']
    sample.to_csv(test_preds_dir, index=False)
